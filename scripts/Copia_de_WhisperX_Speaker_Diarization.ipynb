# %%
# !pip install --q git+https://github.com/m-bain/whisperx.git
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.7/208.7 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 45.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.7/36.7 MB 47.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 98.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 89.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.1/760.1 kB 63.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 68.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 77.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 63.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 101.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 30.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.6/801.6 kB 64.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.9/379.9 kB 42.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 27.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 47.5 MB/s eta 0:00:00
#   Building wheel for whisperx (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
#   Building wheel for julius (setup.py) ... done

# %%
def process_audio_to_openai_training_format(original_list):
    """
    Processes a list of dictionaries into a format suitable for training with OpenAI.
    Each dictionary in the input list is expected to have 'text' and 'speaker' keys.
    The function unifies consecutive dictionaries with the same 'speaker' value,
    merging their 'text' values into a single string, separated by spaces.
    It also transforms 'speaker' into 'role', determining the most frequent speaker
    as 'assistant' and the less frequent as 'user'.

    Parameters:
    original_list (list): A list of dictionaries, each containing 'text' and 'speaker' keys.

    Returns:
    list: A list of unified dictionaries with 'content' and 'role' keys.
    """

    # Filter the list to retain only 'text' and 'speaker' keys from each dictionary
    filtered_list = [
    {
        'text': dic.get('text', ''),
        'speaker': dic.get('speaker', 'user')
    }
    for dic in original_list
    ]


    # Count the frequency of each 'speaker' value
    speaker_frequency = {}
    for dic in filtered_list:
        if dic['speaker'] in speaker_frequency:
            speaker_frequency[dic['speaker']] += 1
        else:
            speaker_frequency[dic['speaker']] = 1

    # Determine the most and least frequent 'speaker'
    most_frequent_speaker = max(speaker_frequency, key=speaker_frequency.get)
    least_frequent_speaker = min(speaker_frequency, key=speaker_frequency.get)

    # Format the list with new keys and values
    formatted_list = [
        {'content': dic['text'], 'role': 'assistant' if dic['speaker'] == most_frequent_speaker else 'user'}
        for dic in filtered_list
    ]

    # List to store the unified result
    unified_list = []

    # Temporary variable to hold the current dictionary while iterating
    temp_dic = None

    # Iterate over each dictionary in the formatted list
    for dic in formatted_list:
        # If there's no temporary dictionary, it's the start of a potential sequence
        if not temp_dic:
            temp_dic = dic
        else:
            # If the 'role' of the current dictionary matches the temporary one,
            # their contents are unified.
            if dic['role'] == temp_dic['role']:
                temp_dic['content'] += " " + dic['content']
            else:
                # If the 'role' is different, add the temporary dictionary to the unified list
                # and start a new temporary dictionary with the current one
                unified_list.append(temp_dic)
                temp_dic = dic

    # Add the last temporary dictionary to the unified list
    if temp_dic:
        unified_list.append(temp_dic)

    # Return the result
    return unified_list

# %%
import os
print(os.getenv("HF_TOKEN"))
from google.colab import userdata
userdata.get('HF_TOKEN')
# Out:
# None
# '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'

# %%
import os
import json
from google.colab import userdata

import whisperx
import gc

# Environment variables
HF_TOKEN = userdata.get('HF_TOKEN')


def  speaker_transcription_and_identify(audio_file):
    """
    This function takes an audio file and returns the transcription of the audio
    and the speaker identification of the audio.

    Parameters:
    audio_file (str): The path to the audio file.

    Returns:
    dict: A dictionary containing the transcription and speaker identification of the audio.
    """
    # Configuration parameters
    device = "cuda"
    batch_size = 3 # reduce if low on GPU mem
    compute_type = "float32" # change to "int8" if low on GPU mem (may reduce accuracy)

    # Whisper procesing
    audio = whisperx.load_audio(audio_file)
    model = whisperx.load_model("large-v2", device, compute_type=compute_type)
    result = model.transcribe(audio, batch_size=batch_size)

    # 2. Align whisper output
    model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
    result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)


    ## Diarization of the text
    diarize_model = whisperx.DiarizationPipeline(use_auth_token=HF_TOKEN,
                                                device=device)

    diarize_segments = diarize_model(audio, min_speakers=2, max_speakers=2)
    result = whisperx.assign_word_speakers(diarize_segments, result)
    # Process the audio to OpenAI training format
    result = process_audio_to_openai_training_format(result["segments"])

    final_format = {"messages": result}
    print(final_format)
    return final_format

def process_directory(audio_directory, output_file):
    """
    Processes all audio files in the given directory and writes the results
    to a JSONL file, one line per audio file.

    Parameters:
    audio_directory (str): The path to the directory containing audio files.
    output_file (str): The path to the JSONL file where results will be saved.
    """
    # Filtrar para obtener solo archivos .wav y .mp3
    audio_files = [f for f in os.listdir(audio_directory)
                   if os.path.isfile(os.path.join(audio_directory, f)) and f.endswith(('.wav', '.mp3'))]

def process_audio_directory(directory_path, output_jsonl_path):
    """
    Process all .mp3 and .wav files in the given directory and append the results
    to a .jsonl file, one entry per audio file.

    Parameters:
    directory_path (str): Path to the directory containing the audio files.
    output_jsonl_path (str): Path to the output .jsonl file where results will be stored.
    """
    # List all files in the directory
    audio_files = [f for f in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, f)) and (f.endswith('.mp3') or f.endswith('.wav'))]

    for audio_file in audio_files:
        audio_path = os.path.join(directory_path, audio_file)
        try:
            # Process the audio file
            result_dict = speaker_transcription_and_identify(audio_path)
            # Append the result to the .jsonl file
            with open(output_jsonl_path, 'a') as outfile:
                json.dump(result_dict, outfile)
                outfile.write('\n')  # Add newline to separate entries
            print(f"Processed: {audio_file}")
        except Exception as e:
            print(f"Error processing {audio_file}: {e}")

if __name__ == "__main__":
    directory_path = "/content/error_files"
    output_jsonl_path = "/content/training_dialer.jsonl"
    process_audio_directory(directory_path, output_jsonl_path)
# Out:
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.1. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.2.1+cu121. Bad things might happen unless you revert torch to 1.x.
# Detected language: en (0.98) in first 30s of audio...
# {'messages': [{'content': ' Yes, may I speak with the business owner, sir, of Yes Chinese Cuisine?', 'role': 'assistant'}, {'content': 'Yeah.', 'role': 'user'}, {'content': "Are you the owner, sir? Yeah. You're the owner of Chinese Cuisine, right?", 'role': 'assistant'}, {'content': 'Yes.', 'role': 'user'}, {'content': "Yes, my name is Nats. Thank you for taking my call. This would only take less than 40 seconds, okay? So firstly, I'm not here to change any of what you have. I respect what you have in the business, okay? Don't get me wrong.  This is regarding about new guidelines, sir, information that would definitely help you save money in your business. It's called zero processing because right now, sir, you're not eligible anymore to pay for the processing fees. If you recall, sir, every time a client swipe their cards right, you pay the processing fees, right?", 'role': 'assistant'}, {'content': "Oh, I don't know yet.", 'role': 'user'}, {'content': "That's the credit card, sir, and the debit card. If your client would pay card, you will pay 1.5 to 3.5% of that.  But with zero processing, sir, you will not pay anything. So you will save money. So for this information, sir, my colleague will call you back tomorrow for less than a minute, and he will tell you how it works. But it's only information. Don't worry. We will not change what you have here, okay? So what time are you available tomorrow, sir? Is it in the morning or in the afternoon, sir?", 'role': 'assistant'}, {'content': " Oh, I don't know. Sometimes it's busy, so I have to talk to my wife. So my wife is not here.", 'role': 'user'}, {'content': "That's good. That's good. So if not tomorrow, on Monday, sir, morning or in the afternoon?", 'role': 'assistant'}, {'content': 'On the Monday, let me try the Monday, so I will have my wife know.', 'role': 'user'}, {'content': "That's good. So on the weekend, you can talk with your wife on the weekend, and then Monday, we can call you back in the afternoon. What time in the afternoon?", 'role': 'assistant'}, {'content': 'What time? What time, sir?', 'role': 'user'}, {'content': ' What time in the afternoon? Monday?', 'role': 'assistant'}, {'content': '3 p.m.', 'role': 'user'}, {'content': 'Okay, 3 p.m. And then your first name is Sun? Sun Yu? Your name is Sun Yu?', 'role': 'assistant'}, {'content': 'Yeah, yeah.', 'role': 'user'}, {'content': 'We can call you on Monday, 3 p.m. at the number 507-3899-886. And last question, Mr. Sun Yu. I do believe you guys are processing at least 5,000 US dollars a month. Just a guesstimate. Is that correct, sir? Because you guys are successful, right?', 'role': 'assistant'}, {'content': " I don't know, so you have to talk about my phone.", 'role': 'user'}, {'content': 'Okay, okay. No worries. On Monday, 3 p.m., okay, Sun Yiu?', 'role': 'assistant'}, {'content': 'Okay.', 'role': 'user'}, {'content': 'Okay, thank you. Bye-bye.', 'role': 'assistant'}]}
# Processed: 20240321-185117_5073899886-all.mp3
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.1. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.2.1+cu121. Bad things might happen unless you revert torch to 1.x.
# Detected language: en (0.98) in first 30s of audio...
# {'messages': [{'content': ' Hello? Hello? May I speak? Yes, sir. May I speak with the business owner of 3MJV Management?', 'role': 'assistant'}, {'content': 'Yeah, this is the business owner. I may have to... Oh!', 'role': 'user'}, {'content': "Pleasure speaking to you, sir. And apologies, by the way. I know you're busy. This is just a quick, what, less than a minute call. Okay? So, firstly, sir, my name here is Nat. I'm from Adventist Bay. And definitely, sir, I'm not here to change any of what you have in the business. I respect what you have here, okay? So, what's this?  This is only regarding about sharing information for you because nowadays this is just a new guideline for business owners just like yourself that are not anymore eligible to pay for the processing fees, which is good news, sir. Instead of you paying 1.5 to 3.5% of processing fees, you will save $1,000. Again, sir, I'm not here to change any of what you have in the business.  So, it's called zero processing. So, my colleague, sir, will definitely give you a call tomorrow for less than a minute and he will share to you how it works, okay? Just to share the information. So, if I may ask, sir, my question here, my good sir, is what would be the best time to ring you back tomorrow? Would it be in the morning or in the afternoon, sir? You're the boss. Tell me the time, sir.", 'role': 'assistant'}, {'content': 'Okay, in the afternoon, maybe like 5, 5. 5?', 'role': 'user'}, {'content': 'Okay, 5 p.m.', 'role': 'assistant'}, {'content': 'will be okay. Yeah, p.m., yeah.', 'role': 'user'}, {'content': '5 p.m. Okay, so, sir, how do I address you? Just the first name will do, sir.', 'role': 'assistant'}, {'content': ' First name?', 'role': 'user'}, {'content': 'Yes, sir.', 'role': 'assistant'}, {'content': 'So what kind of business you guys try to provide?', 'role': 'user'}, {'content': "Even the nickname will do. But sir, this is only information. It's called zero processing, sir. Like for example, your client will be, let's say, swiping a card on your business, debit or credit card, right? So instead of you paying the processing fee of 1.5 to 3.5 percent, sir,  The program is called Zero Processing, meaning, sir, you will not pay anything for the processing fee, zero. You'll save thousands of dollars, okay? Now at the end of the day, sir, if you decide to definitely be interested with the information, it's up to you. But for us, sir, we want to share this information for you so you can upgrade your business and yourself, sir, as well in the business industry. Because there's a few businesses right now are using Zero Processing, sir, okay? So even your nickname will do, sir. If you don't want to give your  First name, that's fine.", 'role': 'assistant'}, {'content': 'Okay, doctor, doctor. Doctor?', 'role': 'user'}, {'content': "Okay, doctor. So doctor, we can call you 5 p.m. tomorrow at 407-361-1925 and definitely you're the good business owner of 3MJV Management. Lastly, doctor, my last question. With your success of your business, I'm pretty sure, sir, at least you're processing 5,000 U.S. dollars a month. Just a guesstimate, I believe, sir, correct?", 'role': 'assistant'}, {'content': 'Every 10,000, yes.', 'role': 'user'}, {'content': " Oh, wow. Okay, correct. Perfect. So, doctor, tomorrow 5 p.m., don't forget, we'll call you. Have a great day. God bless you, sir. You're so kind. Thank you, doctor.", 'role': 'assistant'}, {'content': "All right. Bye-bye. Okay, bye-bye.  If you want to do this after a flood, you have to install a system on top of it. If you don't want to do that, you don't have to.", 'role': 'user'}]}
# Processed: 20240326-155507_4073611925-all.mp3
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.1. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.2.1+cu121. Bad things might happen unless you revert torch to 1.x.
# Detected language: en (0.99) in first 30s of audio...
# {'messages': [{'content': ' Linda Blessing, how may I help you?', 'role': 'user'}, {'content': "Yes, ma'am. I speak with the business owner of Abundant Blessings Thrift Store.", 'role': 'assistant'}, {'content': 'Okay. Hold on, please.', 'role': 'user'}, {'content': "Thank you, ma'am.", 'role': 'assistant'}, {'content': 'Hello. Can I help you?', 'role': 'user'}, {'content': "Yes, ma'am. My name is Nat. Are you the business owner, ma'am, of Abundant Blessings Thrift Store?", 'role': 'assistant'}, {'content': 'Yes, I am.', 'role': 'user'}, {'content': "Yes. Pleasure speaking to you, ma'am. I know you're busy. Apologies. This will only take less than a minute, okay?  So as I mentioned, ma'am, my name is Nance from Aventus Pay. And firstly, ma'am, I'm not here definitely to change any of what you have in the business, okay? I truly respect what you have there. This is only information that we want to share regarding about new guidelines, actually, ma'am, that you should be aware of. Owners are not eligible anymore to pay any processing fees in reference with credit or debit card, okay? It's called zero processing. So what will happen, ma'am, is one of my colleagues will definitely reach you back on Monday.  for just not less than a minute, and he will mention about zero processing, so you would have an idea, okay? So my question here, madam, is what would be the best time to ring you back on Monday? Would it be in the morning or in the afternoon, ma'am? You're the boss.", 'role': 'assistant'}, {'content': 'We are not here on Mondays.', 'role': 'user'}, {'content': "Okay, I'll put that on file.", 'role': 'assistant'}, {'content': 'We are actually closed next week for Easter.', 'role': 'user'}, {'content': "Oh, okay, I'll put that on file. So for the whole week next week, you're closed?", 'role': 'assistant'}, {'content': 'Yep.', 'role': 'user'}, {'content': " So if it's for the whole week, then it's the next week, is that correct?", 'role': 'assistant'}, {'content': 'Yes.', 'role': 'user'}, {'content': "Oh my goodness, that's on the 1st of April.", 'role': 'assistant'}, {'content': 'Yes.', 'role': 'user'}, {'content': "Okay, so on the 1st of April, ma'am, would it be in the morning or in the afternoon? Thank you for mentioning that, the Easter time.", 'role': 'assistant'}, {'content': 'Thursdays.', 'role': 'user'}, {'content': "Thursday, okay. Morning. Morning, like 8 or 9, ma'am?", 'role': 'assistant'}, {'content': 'Like 10.', 'role': 'user'}, {'content': "Okay, no problem, 10 a.m. And how do I address you, ma'am? What's your first name?", 'role': 'assistant'}, {'content': "My name's Loretta.", 'role': 'user'}, {'content': "Loretta, by the way, Loretta,  Lastly, last question, Loretta, okay? This is just a guesstimate, okay? From the first shop that you have right now, ma'am, I believe that you guys are at least processing 5,000 U.S. dollars a month. Just a guesstimate. Is it close? No.", 'role': 'assistant'}, {'content': 'Okay, no worries. Nope, very little.', 'role': 'user'}, {'content': "Okay, on Thursday, that's, let me double check, that's on the 4th, right? Of April. We'll call you at 10 a.m. Have a great day, Loretta. You're the business owner. Yep, bye. Thank you, bye-bye.  Why is it disabled? Jesus.", 'role': 'assistant'}, {'content': ' Thank you.', 'role': 'user'}]}
# Processed: 20240322-155237_7242205100-all.mp3

# %%
import whisperx
import gc
# Out:
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")

# %%
device = "cuda"
batch_size = 4 # reduce if low on GPU mem
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)

# %%
audio_file = "/content/z20240312-233027_8123616141-all.mp3"

# %%
audio = whisperx.load_audio(audio_file)

# %%
model = whisperx.load_model("large-v2", device, compute_type=compute_type)
# Out:
# vocabulary.txt:   0%|          | 0.00/460k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.80k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# No language specified, language will be first be detected for each audio file (increases inference time).
# 100%|█████████████████████████████████████| 16.9M/16.9M [00:01<00:00, 10.9MiB/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.1. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.2.1+cu121. Bad things might happen unless you revert torch to 1.x.

# %%
result = model.transcribe(audio, batch_size=batch_size)
print(result["segments"]) # before alignment

# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model

# 2. Align whisper output
model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)
# Out:
# Detected language: en (1.00) in first 30s of audio...
# [{'text': " Hello? Hello? Yes, who am I speaking with? I'm sorry. It's Dhruvin Patel. Come again? I didn't hear you. You're correct, sir. Mr. Patel? Oh, Patel. Mr. Patel, I believe this number called you. That's why you called us back. Is that correct, sir? Right, right. Okay, so apologies, sir. My name is Nance. I'm from Aventis Bay.", 'start': 0.196, 'end': 25.094}, {'text': " And basically, sir, firstly, I respect what you have, okay? We're not here to change any of what you have, okay, for starters. And this is regarding about new guidelines, because you're a business owner, obviously, sir, what we do is we give information that you guys are no longer required to pay any processing fees in terms of the credit or debit cards, it's called zero processing.", 'start': 25.435, 'end': 45.674}, {'text': " Okay? So that's why we share this information so you guys have an idea that you can save money in terms of the credit and debit card. So it's called zero processing. Now, my colleague, sir, will definitely reach you back tomorrow and he will give you how it works for only less than two minutes and the benefits of zero processing. So my question here, Mr. Patel, is what would be the best time, sir, to reach you back tomorrow? Would it be in the morning, sir, or in the afternoon? You're the boss, sir. Give me the time. Evening. Evening? Like 6 p.m., sir? Would that be perfect?", 'start': 46.067, 'end': 75.947}, {'text': " Yeah. 6 p.m. Sir, Patel at this number 812-361-6141. And what's your business name, sir? Sir, actually, I don't have a business. Oh, you don't have any business? Are you sure? Because this is a business number that we're calling. And so this is a private number and you're only working or what do you do, sir, for a living? Yeah. So, like, I did not get it. Like, what company is it? Like, or what?", 'start': 76.834, 'end': 106.527}, {'text': " I've anticipated what we do, sir. Yes, sir. But like I said, if you do have a business, which definitely, we all know you have, sir. That's why I'm thinking right now. What we do, sir, is we share this information to business owners just like yourself. So definitely, if you're a business owner, definitely you have a credit card machine, right? So every time your client would, let's say, swipe their cards, debit or credit cards, you will pay 1.5 to 3.5% of the processing fees.", 'start': 106.647, 'end': 136.391}, {'text': " Okay? So with this information, Patel, it's zero processing, meaning you will save thousands of dollars, sir. And my colleague will try to reach you back tomorrow for 6 p.m., and he will give you, you know, detailed information, how it works, all the information, sir. So we're not here to change any of what you have. Okay. Just a good perspective. So tomorrow, 6 p.m., sir, and what would be the best business name that we can put here, sir, in my data?", 'start': 136.766, 'end': 160.623}, {'text': " Yeah, so, uh, so I don't have, like, my business is, like, Amazon selling, so it's not Amazon. Oh, wow. Amazon, Amazon, Amazon. So you take credit cards there. Yeah, you take credit cards there as well, sir. I know that, because my friends are in Amazon. But it's not, like, I don't have, like, uh, like, machine that they can swipe. It's just Amazon, Amazon platform they use. So there is no, like, charges on me. Yeah. So with this one, Mr. Patel, uh, this is just a guesstimate.", 'start': 161.51, 'end': 189.684}, {'text': " Would you say, Mr. Patel, in a month's time, you are at least averaging $4,000 to $5,000 a month, or just a guesstimate, sir? You're processing those type of amounts, sir? Just a guesstimate. No. So actually, I'm hardly selling one or two a day. So that's why I'm trying to close the business. So I mean, I'm trying to shut down everything. That's why right now I'm not doing anything.", 'start': 189.923, 'end': 217.517}, {'text': " So besides Amazon, Mr. Patel, I'm pretty sure you have a lot of strategies, because I have friends, you're from Indi ...
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth" to /root/.cache/torch/hub/checkpoints/wav2vec2_fairseq_base_ls960_asr_ls960.pth
# 100%|██████████| 360M/360M [00:01<00:00, 194MB/s]

# %%
result
# Out:
# {'segments': [{'start': 0.236,
#    'end': 0.496,
#    'text': ' Hello?',
#    'words': [{'word': 'Hello?',
#      'start': 0.236,
#      'end': 0.496,
#      'score': 0.699}]},
#   {'start': 1.817,
#    'end': 2.117,
#    'text': 'Hello?',
#    'words': [{'word': 'Hello?',
#      'start': 1.817,
#      'end': 2.117,
#      'score': 0.744}]},
#   {'start': 3.058,
#    'end': 4.319,
#    'text': 'Yes, who am I speaking with?',
#    'words': [{'word': 'Yes,', 'start': 3.058, 'end': 3.258, 'score': 0.818},
#     {'word': 'who', 'start': 3.398, 'end': 3.518, 'score': 0.416},
#     {'word': 'am', 'start': 3.578, 'end': 3.638, 'score': 0.224},
#     {'word': 'I', 'start': 3.679, 'end': 3.779, 'score': 0.433},
#     {'word': 'speaking', 'start': 3.799, 'end': 4.139, 'score': 0.866},
#     {'word': 'with?', 'start': 4.159, 'end': 4.319, 'score': 0.773}]},
#   {'start': 4.359,
#    'end': 4.759,
#    'text': "I'm sorry.",
#    'words': [{'word': "I'm", 'start': 4.359, 'end': 4.459, 'score': 0.475},
#     {'word': 'sorry.', 'start': 4.499, 'end': 4.759, 'score': 0.539}]},
#   {'start': 6.26,
#    'end': 7.721,
#    'text': "It's Dhruvin Patel.",
#    'words': [{'word': "It's", 'start': 6.26, 'end': 6.661, 'score': 0.514},
#     {'word': 'Dhruvin', 'start': 6.701, 'end': 7.101, 'score': 0.66},
#     {'word': 'Patel.', 'start': 7.401, 'end': 7.721, 'score': 0.741}]},
#   {'start': 8.962,
#    'end': 9.683,
#    'text': 'Come again?',
#    'words': [{'word': 'Come', 'start': 8.962, 'end': 9.463, 'score': 0.868},
#     {'word': 'again?', 'start': 9.503, 'end': 9.683, 'score': 0.872}]},
#   {'start': 9.703,
#    'end': 10.844,
#    'text': "I didn't hear you.",
#    'words': [{'word': 'I', 'start': 9.703, 'end': 9.723, 'score': 0.002},
#     {'word': "didn't", 'start': 9.923, 'end': 10.103, 'score': 0.562},
#     {'word': 'hear', 'start': 10.123, 'end': 10.223, 'score': 0.22},
#     {'word': 'you.', 'start': 10.664, 'end': 10.844, 'score': 0.379}]},
#   {'start': 10.864,
#    'end': 11.644,
#    'text': "You're correct, sir.",
#    'words': [{'word': "You're",
#      'start': 10.864,
#      'end': 11.064,
#      'score': 0.407},
#     {'word': 'correct,', 'start': 11.124, 'end': 11.424, 'score': 0.942},
#     {'word': 'sir.', 'start': 11.444, 'end': 11.644, 'score': 0.64}]},
#   {'start': 12.985,
#    'end': 13.566,
#    'text': 'Mr. Patel?',
#    'words': [{'word': 'Mr.', 'start': 12.985, 'end': 13.225, 'score': 0.5},
#     {'word': 'Patel?', 'start': 13.245, 'end': 13.566, 'score': 0.765}]},
#   {'start': 14.526,
#    'end': 15.007,
#    'text': 'Oh, Patel.',
#    'words': [{'word': 'Oh,', 'start': 14.526, 'end': 14.606, 'score': 0.53},
#     {'word': 'Patel.', 'start': 14.646, 'end': 15.007, 'score': 0.85}]},
#   {'start': 15.547,
#    'end': 17.408,
#    'text': 'Mr. Patel, I believe this number called you.',
#    'words': [{'word': 'Mr.', 'start': 15.547, 'end': 15.787, 'score': 0.576},
#     {'word': 'Patel,', 'start': 15.867, 'end': 16.188, 'score': 0.819},
#     {'word': 'I', 'start': 16.228, 'end': 16.288, 'score': 0.682},
#     {'word': 'believe', 'start': 16.328, 'end': 16.588, 'score': 0.813},
#     {'word': 'this', 'start': 16.628, 'end': 16.768, 'score': 0.8},
#     {'word': 'number', 'start': 16.808, 'end': 17.048, 'score': 0.833},
#     {'word': 'called', 'start': 17.108, 'end': 17.288, 'score': 0.899},
#     {'word': 'you.', 'start': 17.308, 'end': 17.408, 'score': 0.814}]},
#   {'start': 17.428,
#    'end': 18.489,
#    'text': "That's why you called us back.",
#    'words': [{'word': "That's",
#      'start': 17.428,
#      'end': 17.609,
#      'score': 0.856},
#     {'word': 'why', 'start': 17.629, 'end': 17.769, 'score': 0.719},
#     {'word': 'you', 'start': 17.789, 'end': 17.909, 'score': 0.769},
#     {'word': 'called', 'start': 17.949, 'end': 18.149, 'score': 0.569},
#     {'word': 'us', 'start': 18.189, 'end': 18.269, 'score': 0.544},
#     {'word': 'back.', 'start': 18.329, 'end': 18.489, 'score': 0.866}]},
#   {'start': 18.529,
#    'end': 19.15,
#    'text': 'Is that correct, sir?',
#    'words': [{'word': 'Is', 'start': 18.529, 'end': 18.589, 'score': 0.602},
#     {'word': 'that', 'start': 18.629, 'end': 18.709, 'score': 0.516},
#     {'word': 'correct,', 'start': 18.749, 'end': 18.99, 'score': 0.738},
#     {'word': 'sir?', 'start': 19.01, 'end': 19.15, 'score': 0.447}]},
#   {'start': 20.21,
#    'end': 20.751,
#    'text': 'Right, right.',
#    'words': [{'word': 'Right,', 'start': 20.21, 'end': 20.451, 'score': 0.649},
#     {'word': 'right.', 'start': 20.491, 'end': 20.751, 'score': 0.635}]},
#   {'start': 21.251,
#    'end': 22.372,
#    'text': 'Okay, so apologies, sir.',
#    'words': [{'word': 'Okay,', 'start': 21.251, 'end': 21.411, 'score': 0.44},
#     {'word': 'so', 'start': 21.451, 'end': 21.611, 'score': 0.917},
#     {'word': 'apologies,', 'start': 21.652, 'end': 22.092, 'score': 0.583},
#     {'word': 'sir.', 'start': 22.132, 'end': 22.372, 'score': 0.815}]},
#   {'start': 22.992,
#    'end': 23.773,
#    'text': 'My name is Nance.',
#    'words': [{'word': 'My', 'start': 22.992, 'end': 23.113, 'score': 0.867},
#     {'word': 'name', 'start': 23.153, 'end': 23.293, 'score': 0.812},
#     {'word': 'is', 'start': 23.333, 'end': 23.413, 'score': 0.668},
#     {'word': 'Nance.', 'start': 23.453, 'end': 23.773, 'score': 0.589}]},
#   {'start': 23.933,
#    'end': 24.934,
#    'text': "I'm from Aventis Bay.",
#    'words': [{'word': "I'm", 'start': 23.933, 'end': 24.033, 'score': 0.105},
#     {'word': 'from', 'start': 24.073, 'end': 24.213, 'score': 0.839},
#     {'word': 'Aventis', 'start': 24.293, 'end': 24.654, 'score': 0.614},
#     {'word': 'Bay.', 'start': 24.754, 'end': 24.934, 'score': 0.849}]},
#   {'start': 25.535,
#    'end': 28.838,
#    'text': ' And basically, sir, firstly, I respect what you have, okay?',
#    'words': [{'word': 'And', 'start': 25.535, 'end': 25.595, 'score': 0.485},
#     {'word': 'basically,', 'start': 25.635, 'end': 26.076, 'score': 0.822},
#     {'word': 'sir,', 'start': 26.116, 'end': 26.276, 'score': 0.702},
#     {'word': 'firstly,', 'start': 26.296, 'end': 26.736, 'score': 0.804},
#     {'word': 'I', 'start': 27.657, 'end': 27.717, 'score': 0.86},
#     {'word': 'respect', 'start': 27.757, 'end': 28.097, 'score': 0.86},
#     {'word': 'what', 'start': 28.138, 'end': 28.258, 'score': 0.875},
#     {'word': 'you', 'start': 28.278, 'end': 28.398, 'score': 0.984},
#     {'word': 'have,', 'start': 28.438, 'end': 28.558, 'score': 0.942},
#     {'word': 'okay?', 'start': 28.638, 'end': 28.838, 'score': 0.585}]},
#   {'start': 28.858,
#    'end': 32.101,
#    'text': "We're not here to change any of what you have, okay, for starters.",
#    'words': [{'word': "We're", 'start': 28.858, 'end': 28.978, 'score': 0.418},
#     {'word': 'not', 'start': 29.018, 'end': 29.118, 'score': 0.926},
#     {'word': 'here', 'start': 29.158, 'end': 29.279, 'score': 0.392},
#     {'word': 'to', 'start': 29.299, 'end': 29.379, 'score': 0.582},
#     {'word': 'change', 'start': 29.439, 'end': 29.759, 'score': 0.76},
#     {'word': 'any', 'start': 29.799, 'end': 29.939, 'score': 0.799},
#     {'word': 'of', 'start': 29.959, 'end': 29.999, 'score': 0.722},
#     {'word': 'what', 'start': 30.039, 'end': 30.179, 'score': 0.903},
#     {'word': 'you', 'start': 30.219, 'end': 30.32, 'score': 0.992},
#     {'word': 'have,', 'start': 30.36, 'end': 30.56, 'score': 0.936},
#     {'word': 'okay,', 'start': 30.68, 'end': 30.94, 'score': 0.752},
#     {'word': 'for', 'start': 30.98, 'end': 31.16, 'score': 0.847},
#     {'word': 'starters.', 'start': 31.18, 'end': 32.101, 'score': 0.775}]},
#   {'start': 32.602,
#    'end': 45.614,
#    'text': "And this is regarding about new guidelines, because you're a business owner, obviously, sir, what we do is we give information that you guys are no longer required to pay any processing fees in terms of the credit or debit cards, it's called zero processing.",
#    'words': [{'word': 'And', 'start': 32.602, 'end': 32.702, 'score': 0.871},
#     {'word': 'this', 'start': 32.742, 'end': 32.922, 'score': 0.89},
#     {'word': 'is', 'start': 32.942, 'end': 32.982, 'score': 0.696},
#     {'word': 'regarding', 'start': 33.062, 'end': 33.483, 'score': 0.864},
#     {'word': 'about', 'start': 33.563, 'end': 33.883, 'score': 0.87},
#     {'word': 'new', 'start': 33.903, 'end': 34.223, 'score': 0.482},
#     {'word': 'guidelines,', 'start': 34.243, 'end': 34.744, 'score': 0.793},
#     {'word': 'because', 'start': 34.944, 'end': 35.184, 'score': 0.9},
#     {'word': "you're", 'start': 35.204, 'end': 35.364, 'score': 0.777},
#     {'word': 'a', 'start': 35.384, 'end': 35.404, 'score': 0.679},
#     {'word': 'business', 'start': 35.464, 'end': 35.785, 'score': 0.853},
#     {'word': 'owner,', 'start': 35.905, 'end': 36.225, 'score': 0.513},
#     {'word': 'obviously,', 'start': 36.325, 'end': 36.686, 'score': 0.946},
#     {'word': 'sir,', 'start': 36.746, 'end': 36.926, 'score': 0.796},
#     {'word': 'what', 'start': 36.946, 'end': 37.106, 'score': 0.7},
#     {'word': 'we', 'start': 37.126, 'end': 37.246, 'score': 0.734},
#     {'word': 'do', 'start': 37.286, 'end': 37.346, 'score': 0.286},
#     {'word': 'is', 'start': 37.386, 'end': 37.446, 'score': 0.226},
#     {'word': 'we', 'start': 37.466, 'end': 37.606, 'score': 0.78},
#     {'word': 'give', 'start': 37.626, 'end': 37.767, 'score': 0.957},
#     {'word': 'information', 'start': 37.827, 'end': 38.347, 'score': 0.894},
#     {'word': 'that', 'start': 38.367, 'end': 38.507, 'score': 0.763},
#     {'word': 'you', 'start': 38.968, 'end': 39.668, 'score': 0.766},
#     {'word': 'guys', 'start': 39.688, 'end': 39.849, 'score': 0.69},
#     {'word': 'are', 'start': 39.889, 'end': 39.989, 'score': 0.834},
#     {'word': 'no', 'start': 40.029, 'end': 40.109, 'score': 0.869},
#     {'word': 'longer', 'start': 40.129, 'end': 40.369, 'score': 0.828},
#     {'word': 'required', 'start': 40.429, 'end': 40.749, 'score': 0.871},
#     {'word': 'to', 'start': 40.789, 'end': 40.849, 'score': 0.876},
#     {'word': 'pay', 'start': 40.91, 'end': 41.05, 'score': 0.763},
#     {'word': 'any', 'start': 41.23, 'end': 41.39, 'score': 0.927},
#     {'word': 'processing', 'start': 41.55, 'end': 42.191, 'score': 0.824},
#     {'word': 'fees', 'start': 42.371, 'end': 42.651, 'score': 0.76},
#     {'word': 'in', 'start': 42.691, 'end': 42.771, 'score': 0.986},
#     {'word': 'terms', 'start': 42.811, 'end': 43.072, 'score': 0.836},
#     {'word': 'of', 'start': 43.132, 'end': 43.232, 'score': 0.792},
#     {'word': 'the', 'start': 43.252, 'end': 43.312, 'score': 0.646},
#     {'word': 'credit', 'start': 43.392, 'end': 43.692, 'score': 0.882},
#     {'word': 'or', 'start': 43.732, 'end': 43.812, 'score': 0.653},
#     {'word': 'debit', 'start': 43.872, 'end': 44.133, 'score': 0.753},
#     {'word': 'cards,', 'start': 44.153, 'end': 44.433, 'score': 0.608},
#     {'word': "it's", 'start': 44.473, 'end': 44.553, 'score': 0.015},
#     {'word': 'called', 'start': 44.653, 'end': 44.813, 'score': 0.642},
#     {'word': 'zero', 'start': 44.853, 'end': 45.113, 'score': 0.651},
#     {'word': 'processing.', 'start': 45.174, 'end': 45.614, 'score': 0.538}]},
#   {'start': 46.087,
#    'end': 46.287,
#    'text': ' Okay?',
#    'words': [{'word': 'Okay?',
#      'start': 46.087,
#      'end': 46.287,
#      'score': 0.475}]},
#   {'start': 46.587,
#    'end': 53.352,
#    'text': "So that's why we share this information so you guys have an idea that you can save money in terms of the credit and debit card.",
#    'words': [{'word': 'So', 'start': 46.587, 'end': 46.687, 'score': 0.994},
#     {'word': "that's", 'start': 46.727, 'end': 46.868, 'score': 0.975},
#     {'word': 'why', 'start': 46.908, 'end': 47.008, 'score': 0.701},
#     {'word': 'we', 'start': 47.048, 'end': 47.148, 'score': 0.734},
#     {'word': 'share', 'start': 47.168, 'end': 47.348, 'score': 0.813},
#     {'word': 'this', 'start': 47.368, 'end': 47.488, 'score': 0.856},
#     {'word': 'information', 'start': 47.528, 'end': 48.048, 'score': 0.893},
#     {'word': 'so', 'start': 48.208, 'end': 48.329, 'score': 0.735},
#     {'word': 'you', 'start': 48.349, 'end': 48.429, 'score': 0.365},
#     {'word': 'guys', 'start': 48.449, 'end': 48.649, 'score': 0.543},
#     {'word': 'have', 'start': 48.669, 'end': 49.149, 'score': 0.538},
#     {'word': 'an', 'start': 49.309, 'end': 49.389, 'score': 0.655},
#     {'word': 'idea', 'start': 49.449, 'end': 49.81, 'score': 0.924},
#     {'word': 'that', 'start': 50.21, 'end': 50.33, 'score': 0.885},
#     {'word': 'you', 'start': 50.35, 'end': 50.45, 'score': 0.987},
#     {'word': 'can', 'start': 50.49, 'end': 50.63, 'score': 0.982},
#     {'word': 'save', 'start': 50.71, 'end': 50.95, 'score': 0.798},
#     {'word': 'money', 'start': 51.03, 'end': 51.25, 'score': 0.829},
#     {'word': 'in', 'start': 51.691, 'end': 51.851, 'score': 0.558},
#     {'word': 'terms', 'start': 51.891, 'end': 52.091, 'score': 0.577},
#     {'word': 'of', 'start': 52.131, 'end': 52.291, 'score': 0.546},
#     {'word': 'the', 'start': 52.311, 'end': 52.431, 'score': 0.349},
#     {'word': 'credit', 'start': 52.471, 'end': 52.651, 'score': 0.371},
#     {'word': 'and', 'start': 52.691, 'end': 52.832, 'score': 0.294},
#     {'word': 'debit', 'start': 52.892, 'end': 53.132, 'score': 0.669},
#     {'word': 'card.', 'start': 53.152, 'end': 53.352, 'score': 0.731}]},
#   {'start': 53.652,
#    'end': 54.793,
#    'text': "So it's called zero processing.",
#    'words': [{'word': 'So', 'start': 53.652, 'end': 53.752, 'score': 0.742},
#     {'word': "it's", 'start': 53.772, 'end': 53.852, 'score': 0.03},
#     {'word': 'called', 'start': 53.872, 'end': 54.012, 'score': 0.328},
#     {'word': 'zero', 'start': 54.032, 'end': 54.313, 'score': 0.786},
#     {'word': 'processing.', 'start': 54.333, 'end': 54.793, 'score': 0.693}]},
#   {'start': 54.833,
#    'end': 63.018,
#    'text': 'Now, my colleague, sir, will definitely reach you back tomorrow and he will give you how it works for only less than two minutes and the benefits of zero processing.',
#    'words': [{'word': 'Now,', 'start': 54.833, 'end': 54.973, 'score': 0.973},
#     {'word': 'my', 'start': 55.053, 'end': 55.233, 'score': 0.98},
#     {'word': 'colleague,', 'start': 55.313, 'end': 55.653, 'score': 0.532},
#     {'word': 'sir,', 'start': 55.673, 'end': 55.834, 'score': 0.536},
#     {'word': 'will', 'start': 55.854, 'end': 56.034, 'score': 0.78},
#     {'word': 'definitely', 'start': 56.114, 'end': 56.534, 'score': 0.915},
#     {'word': 'reach', 'start': 56.594, 'end': 56.754, 'score': 0.907},
#     {'word': 'you', 'start': 56.794, 'end': 56.894, 'score': 0.98},
#     {'word': 'back', 'start': 56.934, 'end': 57.074, 'score': 0.915},
#     {'word': 'tomorrow', 'start': 57.134, 'end': 57.415, 'score': 0.54},
#     {'word': 'and', 'start': 57.435, 'end': 57.515, 'score': 0.3},
#     {'word': 'he', 'start': 57.555, 'end': 57.635, 'score': 0.485},
#     {'word': 'will', 'start': 57.655, 'end': 57.835, 'score': 0.888},
#     {'word': 'give', 'start': 58.255, 'end': 58.435, 'score': 0.784},
#     {'word': 'you', 'start': 58.475, 'end': 58.615, 'score': 0.805},
#     {'word': 'how', 'start': 59.096, 'end': 59.256, 'score': 0.895},
#     {'word': 'it', 'start': 59.316, 'end': 59.376, 'score': 0.837},
#     {'word': 'works', 'start': 59.416, 'end': 59.716, 'score': 0.838},
#     {'word': 'for', 'start': 59.836, 'end': 59.976, 'score': 0.758},
#     {'word': 'only', 'start': 60.016, 'end': 60.216, 'score': 0.891},
#     {'word': 'less', 'start': 60.297, 'end': 60.477, 'score': 0.6},
#     {'word': 'than', 'start': 60.497, 'end': 60.597, 'score': 0.382},
#     {'word': 'two', 'start': 60.637, 'end': 60.777, 'score': 0.825},
#     {'word': 'minutes', 'start': 60.797, 'end': 61.057, 'score': 0.782},
#     {'word': 'and', 'start': 61.197, 'end': 61.297, 'score': 0.674},
#     {'word': 'the', 'start': 61.337, 'end': 61.597, 'score': 0.752},
#     {'word': 'benefits', 'start': 61.637, 'end': 61.998, 'score': 0.882},
#     {'word': 'of', 'start': 62.038, 'end': 62.118, 'score': 0.848},
#     {'word': 'zero', 'start': 62.318, 'end': 62.538, 'score': 0.434},
#     {'word': 'processing.', 'start': 62.558, 'end': 63.018, 'score': 0.752}]},
#   {'start': 63.038,
#    'end': 67.181,
#    'text': 'So my question here, Mr. Patel, is what would be the best time, sir, to reach you back tomorrow?',
#    'words': [{'word': 'So', 'start': 63.038, 'end': 63.178, 'score': 0.921},
#     {'word': 'my', 'start': 63.218, 'end': 63.359, 'score': 0.883},
#     {'word': 'question', 'start': 63.419, 'end': 63.739, 'score': 0.887},
#     {'word': 'here,', 'start': 63.759, 'end': 63.879, 'score': 0.588},
#     {'word': 'Mr.', 'start': 63.919, 'end': 64.159, 'score': 0.732},
#     {'word': 'Patel,', 'start': 64.219, 'end': 64.499, 'score': 0.811},
#     {'word': 'is', 'start': 64.519, 'end': 64.619, 'score': 0.678},
#     {'word': 'what', 'start': 65.04, 'end': 65.16, 'score': 0.901},
#     {'word': 'would', 'start': 65.18, 'end': 65.32, 'score': 0.851},
#     {'word': 'be', 'start': 65.34, 'end': 65.42, 'score': 0.502},
#     {'word': 'the', 'start': 65.44, 'end': 65.52, 'score': 0.819},
#     {'word': 'best', 'start': 65.56, 'end': 65.72, 'score': 0.907},
#     {'word': 'time,', 'start': 65.76, 'end': 65.94, 'score': 0.717},
#     {'word': 'sir,', 'start': 65.98, 'end': 66.14, 'score': 0.767},
#     {'word': 'to', 'start': 66.241, 'end': 66.341, 'score': 0.99},
#     {'word': 'reach', 'start': 66.381, 'end': 66.521, 'score': 0.533},
#     {'word': 'you', 'start': 66.561, 'end': 66.661, 'score': 0.861},
#     {'word': 'back', 'start': 66.681, 'end': 66.821, 'score': 0.784},
#     {'word': 'tomorrow?', 'start': 66.861, 'end': 67.181, 'score': 0.847}]},
#   {'start': 67.201,
#    'end': 69.202,
#    'text': 'Would it be in the morning, sir, or in the afternoon?',
#    'words': [{'word': 'Would', 'start': 67.201, 'end': 67.361, 'score': 0.793},
#     {'word': 'it', 'start': 67.401, 'end': 67.441, 'score': 0.946},
#     {'word': 'be', 'start': 67.481, 'end': 67.541, 'score': 0.705},
#     {'word': 'in', 'start': 67.561, 'end': 67.621, 'score': 0.718},
#     {'word': 'the', 'start': 67.661, 'end': 67.742, 'score': 0.905},
#     {'word': 'morning,', 'start': 67.782, 'end': 68.062, 'score': 0.884},
#     {'word': 'sir,', 'start': 68.082, 'end': 68.322, 'score': 0.891},
#     {'word': 'or', 'start': 68.422, 'end': 68.482, 'score': 0.987},
#     {'word': 'in', 'start': 68.602, 'end': 68.662, 'score': 0.991},
#     {'word': 'the', 'start': 68.682, 'end': 68.782, 'score': 0.813},
#     {'word': 'afternoon?', 'start': 68.842, 'end': 69.202, 'score': 0.952}]},
#   {'start': 69.283,
#    'end': 69.943,
#    'text': "You're the boss, sir.",
#    'words': [{'word': "You're",
#      'start': 69.283,
#      'end': 69.423,
#      'score': 0.642},
#     {'word': 'the', 'start': 69.463, 'end': 69.563, 'score': 0.434},
#     {'word': 'boss,', 'start': 69.583, 'end': 69.743, 'score': 0.529},
#     {'word': 'sir.', 'start': 69.763, 'end': 69.943, 'score': 0.669}]},
#   {'start': 70.003,
#    'end': 70.543,
#    'text': 'Give me the time.',
#    'words': [{'word': 'Give', 'start': 70.003, 'end': 70.143, 'score': 0.956},
#     {'word': 'me', 'start': 70.163, 'end': 70.223, 'score': 0.259},
#     {'word': 'the', 'start': 70.243, 'end': 70.323, 'score': 0.636},
#     {'word': 'time.', 'start': 70.363, 'end': 70.543, 'score': 0.963}]},
#   {'start': 72.685,
#    'end': 72.965,
#    'text': 'Evening.',
#    'words': [{'word': 'Evening.',
#      'start': 72.685,
#      'end': 72.965,
#      'score': 0.769}]},
#   {'start': 73.946,
#    'end': 74.186,
#    'text': 'Evening?',
#    'words': [{'word': 'Evening?',
#      'start': 73.946,
#      'end': 74.186,
#      'score': 0.979}]},
#   {'start': 74.246,
#    'end': 75.086,
#    'text': 'Like 6 p.m., sir?',
#    'words': [{'word': 'Like', 'start': 74.246, 'end': 74.366, 'score': 0.863},
#     {'word': '6'},
#     {'word': 'p.m.,', 'start': 74.666, 'end': 74.926, 'score': 0.684},
#     {'word': 'sir?', 'start': 74.946, 'end': 75.086, 'score': 0.478}]},
#   {'start': 75.126,
#    'end': 75.827,
#    'text': 'Would that be perfect?',
#    'words': [{'word': 'Would', 'start': 75.126, 'end': 75.247, 'score': 0.711},
#     {'word': 'that', 'start': 75.267, 'end': 75.367, 'score': 0.416},
#     {'word': 'be', 'start': 75.387, 'end': 75.487, 'score': 0.793},
#     {'word': 'perfect?', 'start': 75.527, 'end': 75.827, 'score': 0.963}]},
#   {'start': 76.914,
#    'end': 77.154,
#    'text': ' Yeah.',
#    'words': [{'word': 'Yeah.',
#      'start': 76.914,
#      'end': 77.154,
#      'score': 0.666}]},
#   {'start': 77.174,
#    'end': 78.375,
#    'text': '6 p.m.',
#    'words': [{'word': '6'},
#     {'word': 'p.m.', 'start': 78.175, 'end': 78.375, 'score': 0.326}]},
#   {'start': 78.455,
#    'end': 79.975,
#    'text': 'Sir, Patel at this number 812-361-6141.',
#    'words': [{'word': 'Sir,', 'start': 78.455, 'end': 78.555, 'score': 0.555},
#     {'word': 'Patel', 'start': 78.595, 'end': 78.875, 'score': 0.866},
#     {'word': 'at', 'start': 78.895, 'end': 78.995, 'score': 0.612},
#     {'word': 'this', 'start': 79.015, 'end': 79.155, 'score': 0.702},
#     {'word': 'number', 'start': 79.195, 'end': 79.475, 'score': 0.903},
#     {'word': '812-361-6141.', 'start': 79.495, 'end': 79.975, 'score': 0.25}]},
#   {'start': 81.976,
#    'end': 83.717,
#    'text': "And what's your business name, sir?",
#    'words': [{'word': 'And', 'start': 81.976, 'end': 82.637, 'score': 0.7},
#     {'word': "what's", 'start': 82.677, 'end': 82.837, 'score': 0.752},
#     {'word': 'your', 'start': 82.877, 'end': 83.017, 'score': 0.867},
#     {'word': 'business', 'start': 83.057, 'end': 83.337, 'score': 0.916},
#     {'word': 'name,', 'start': 83.357, 'end': 83.537, 'score': 0.914},
#     {'word': 'sir?', 'start': 83.577, 'end': 83.717, 'score': 0.847}]},
#   {'start': 83.737,
#    'end': 87.959,
#    'text': "Sir, actually, I don't have a business.",
#    'words': [{'word': 'Sir,', 'start': 83.737, 'end': 86.298, 'score': 0.747},
#     {'word': 'actually,', 'start': 86.798, 'end': 87.119, 'score': 0.67},
#     {'word': 'I', 'start': 87.139, 'end': 87.179, 'score': 0.402},
#     {'word': "don't", 'start': 87.199, 'end': 87.319, 'score': 0.382},
#     {'word': 'have', 'start': 87.339, 'end': 87.459, 'score': 0.679},
#     {'word': 'a', 'start': 87.479, 'end': 87.499, 'score': 0.007},
#     {'word': 'business.', 'start': 87.519, 'end': 87.959, 'score': 0.804}]},
#   {'start': 88.899,
#    'end': 90.3,
#    'text': "Oh, you don't have any business?",
#    'words': [{'word': 'Oh,', 'start': 88.899, 'end': 89.079, 'score': 0.691},
#     {'word': 'you', 'start': 89.42, 'end': 89.5, 'score': 0.918},
#     {'word': "don't", 'start': 89.54, 'end': 89.66, 'score': 0.899},
#     {'word': 'have', 'start': 89.68, 'end': 89.8, 'score': 0.825},
#     {'word': 'any', 'start': 89.84, 'end': 89.92, 'score': 0.998},
#     {'word': 'business?', 'start': 89.96, 'end': 90.3, 'score': 0.862}]},
#   {'start': 90.32,
#    'end': 91.06,
#    'text': 'Are you sure?',
#    'words': [{'word': 'Are', 'start': 90.32, 'end': 90.38, 'score': 0.066},
#     {'word': 'you', 'start': 90.76, 'end': 90.84, 'score': 0.687},
#     {'word': 'sure?', 'start': 90.88, 'end': 91.06, 'score': 0.686}]},
#   {'start': 91.08,
#    'end': 93.101,
#    'text': "Because this is a business number that we're calling.",
#    'words': [{'word': 'Because', 'start': 91.08, 'end': 91.38, 'score': 0.718},
#     {'word': 'this', 'start': 91.4, 'end': 91.54, 'score': 0.818},
#     {'word': 'is', 'start': 91.58, 'end': 91.64, 'score': 0.666},
#     {'word': 'a', 'start': 91.68, 'end': 91.741, 'score': 0.416},
#     {'word': 'business', 'start': 91.761, 'end': 92.041, 'score': 0.588},
#     {'word': 'number', 'start': 92.061, 'end': 92.241, 'score': 0.49},
#     {'word': 'that', 'start': 92.261, 'end': 92.501, 'score': 0.326},
#     {'word': "we're", 'start': 92.541, 'end': 92.701, 'score': 0.313},
#     {'word': 'calling.', 'start': 92.721, 'end': 93.101, 'score': 0.877}]},
#   {'start': 93.681,
#    'end': 99.644,
#    'text': "And so this is a private number and you're only working or what do you do, sir, for a living?",
#    'words': [{'word': 'And', 'start': 93.681, 'end': 93.801, 'score': 0.9},
#     {'word': 'so', 'start': 94.142, 'end': 94.622, 'score': 0.861},
#     {'word': 'this', 'start': 94.762, 'end': 94.902, 'score': 0.968},
#     {'word': 'is', 'start': 94.962, 'end': 95.042, 'score': 0.732},
#     {'word': 'a', 'start': 95.082, 'end': 95.122, 'score': 0.506},
#     {'word': 'private', 'start': 95.182, 'end': 95.502, 'score': 0.879},
#     {'word': 'number', 'start': 95.542, 'end': 95.802, 'score': 0.917},
#     {'word': 'and', 'start': 96.002, 'end': 96.122, 'score': 0.812},
#     {'word': "you're", 'start': 96.763, 'end': 97.023, 'score': 0.763},
#     {'word': 'only', 'start': 97.143, 'end': 97.363, 'score': 0.974},
#     {'word': 'working', 'start': 97.403, 'end': 97.743, 'score': 0.896},
#     {'word': 'or', 'start': 97.883, 'end': 98.063, 'score': 0.655},
#     {'word': 'what', 'start': 98.483, 'end': 98.624, 'score': 0.901},
#     {'word': 'do', 'start': 98.644, 'end': 98.724, 'score': 0.887},
#     {'word': 'you', 'start': 98.744, 'end': 98.824, 'score': 0.977},
#     {'word': 'do,', 'start': 98.864, 'end': 98.944, 'score': 0.985},
#     {'word': 'sir,', 'start': 98.984, 'end': 99.144, 'score': 0.76},
#     {'word': 'for', 'start': 99.164, 'end': 99.304, 'score': 0.882},
#     {'word': 'a', 'start': 99.324, 'end': 99.344, 'score': 0.839},
#     {'word': 'living?', 'start': 99.384, 'end': 99.644, 'score': 0.91}]},
#   {'start': 101.365,
#    'end': 101.805,
#    'text': 'Yeah.',
#    'words': [{'word': 'Yeah.',
#      'start': 101.365,
#      'end': 101.805,
#      'score': 0.709}]},
#   {'start': 102.225,
#    'end': 104.426,
#    'text': 'So, like, I did not get it.',
#    'words': [{'word': 'So,', 'start': 102.225, 'end': 102.425, 'score': 0.958},
#     {'word': 'like,', 'start': 102.785, 'end': 102.985, 'score': 0.792},
#     {'word': 'I', 'start': 103.666, 'end': 103.726, 'score': 0.967},
#     {'word': 'did', 'start': 103.746, 'end': 103.886, 'score': 0.939},
#     {'word': 'not', 'start': 103.926, 'end': 104.046, 'score': 0.984},
#     {'word': 'get', 'start': 104.086, 'end': 104.306, 'score': 0.656},
#     {'word': 'it.', 'start': 104.346, 'end': 104.426, 'score': 0.814}]},
#   {'start': 104.466,
#    'end': 105.747,
#    'text': 'Like, what company is it?',
#    'words': [{'word': 'Like,',
#      'start': 104.466,
#      'end': 104.646,
#      'score': 0.782},
#     {'word': 'what', 'start': 104.666, 'end': 105.066, 'score': 0.63},
#     {'word': 'company', 'start': 105.126, 'end': 105.487, 'score': 0.929},
#     {'word': 'is', 'start': 105.527, 'end': 105.607, 'score': 0.77},
#     {'word': 'it?', 'start': 105.687, 'end': 105.747, 'score': 0.848}]},
#   {'start': 105.787,
#    'end': 106.327,
#    'text': 'Like, or what?',
#    'words': [{'word': 'Like,',
#      'start': 105.787,
#      'end': 105.947,
#      'score': 0.861},
#     {'word': 'or', 'start': 106.007, 'end': 106.107, 'score': 0.598},
#     {'word': 'what?', 'start': 106.167, 'end': 106.327, 'score': 0.414}]},
#   {'start': 107.388,
#    'end': 110.39,
#    'text': " I've anticipated what we do, sir.",
#    'words': [{'word': "I've",
#      'start': 107.388,
#      'end': 108.989,
#      'score': 0.689},
#     {'word': 'anticipated', 'start': 109.029, 'end': 109.589, 'score': 0.929},
#     {'word': 'what', 'start': 109.609, 'end': 109.689, 'score': 0.079},
#     {'word': 'we', 'start': 109.709, 'end': 109.99, 'score': 0.589},
#     {'word': 'do,', 'start': 110.01, 'end': 110.15, 'score': 0.76},
#     {'word': 'sir.', 'start': 110.17, 'end': 110.39, 'score': 0.619}]},
#   {'start': 111.191,
#    'end': 111.591,
#    'text': 'Yes, sir.',
#    'words': [{'word': 'Yes,',
#      'start': 111.191,
#      'end': 111.371,
#      'score': 0.985},
#     {'word': 'sir.', 'start': 111.411, 'end': 111.591, 'score': 0.769}]},
#   {'start': 111.751,
#    'end': 116.955,
#    'text': 'But like I said, if you do have a business, which definitely, we all know you have, sir.',
#    'words': [{'word': 'But', 'start': 111.751, 'end': 112.272, 'score': 0.734},
#     {'word': 'like', 'start': 112.592, 'end': 112.772, 'score': 0.838},
#     {'word': 'I', 'start': 112.812, 'end': 112.872, 'score': 0.694},
#     {'word': 'said,', 'start': 112.912, 'end': 113.212, 'score': 0.651},
#     {'word': 'if', 'start': 113.653, 'end': 113.733, 'score': 0.994},
#     {'word': 'you', 'start': 113.773, 'end': 113.893, 'score': 0.892},
#     {'word': 'do', 'start': 113.913, 'end': 114.033, 'score': 0.978},
#     {'word': 'have', 'start': 114.053, 'end': 114.193, 'score': 0.85},
#     {'word': 'a', 'start': 114.233, 'end': 114.253, 'score': 0.984},
#     {'word': 'business,', 'start': 114.313, 'end': 114.633, 'score': 0.923},
#     {'word': 'which', 'start': 114.653, 'end': 114.814, 'score': 0.898},
#     {'word': 'definitely,', 'start': 114.834, 'end': 115.554, 'score': 0.374},
#     {'word': 'we', 'start': 115.614, 'end': 116.075, 'score': 0.736},
#     {'word': 'all', 'start': 116.135, 'end': 116.235, 'score': 0.806},
#     {'word': 'know', 'start': 116.275, 'end': 116.435, 'score': 0.93},
#     {'word': 'you', 'start': 116.455, 'end': 116.595, 'score': 0.828},
#     {'word': 'have,', 'start': 116.635, 'end': 116.795, 'score': 0.873},
#     {'word': 'sir.', 'start': 116.835, 'end': 116.955, 'score': 0.677}]},
#   {'start': 116.995,
#    'end': 118.617,
#    'text': "That's why I'm thinking right now.",
#    'words': [{'word': "That's",
#      'start': 116.995,
#      'end': 117.196,
#      'score': 0.27},
#     {'word': 'why', 'start': 117.236, 'end': 117.596, 'score': 0.615},
#     {'word': "I'm", 'start': 117.776, 'end': 117.896, 'score': 0.698},
#     {'word': 'thinking', 'start': 117.936, 'end': 118.256, 'score': 0.753},
#     {'word': 'right', 'start': 118.296, 'end': 118.437, 'score': 0.496},
#     {'word': 'now.', 'start': 118.477, 'end': 118.617, 'score': 0.921}]},
#   {'start': 119.337,
#    'end': 122.68,
#    'text': 'What we do, sir, is we share this information to business owners just like yourself.',
#    'words': [{'word': 'What', 'start': 119.337, 'end': 119.477, 'score': 0.79},
#     {'word': 'we', 'start': 119.497, 'end': 119.637, 'score': 0.618},
#     {'word': 'do,', 'start': 119.678, 'end': 119.758, 'score': 0.74},
#     {'word': 'sir,', 'start': 119.778, 'end': 119.878, 'score': 0.732},
#     {'word': 'is', 'start': 119.918, 'end': 119.978, 'score': 0.441},
#     {'word': 'we', 'start': 120.018, 'end': 120.138, 'score': 0.826},
#     {'word': 'share', 'start': 120.178, 'end': 120.358, 'score': 0.844},
#     {'word': 'this', 'start': 120.378, 'end': 120.518, 'score': 0.71},
#     {'word': 'information', 'start': 120.558, 'end': 121.119, 'score': 0.938},
#     {'word': 'to', 'start': 121.139, 'end': 121.259, 'score': 0.845},
#     {'word': 'business', 'start': 121.279, 'end': 121.579, 'score': 0.868},
#     {'word': 'owners', 'start': 121.639, 'end': 121.879, 'score': 0.759},
#     {'word': 'just', 'start': 121.919, 'end': 122.099, 'score': 0.757},
#     {'word': 'like', 'start': 122.119, 'end': 122.26, 'score': 0.972},
#     {'word': 'yourself.', 'start': 122.3, 'end': 122.68, 'score': 0.848}]},
#   {'start': 123.24,
#    'end': 126.863,
#    'text': "So definitely, if you're a business owner, definitely you have a credit card machine, right?",
#    'words': [{'word': 'So', 'start': 123.24, 'end': 123.481, 'score': 0.715},
#     {'word': 'definitely,', 'start': 123.541, 'end': 123.961, 'score': 0.751},
#     {'word': 'if', 'start': 124.021, 'end': 124.101, 'score': 0.762},
#     {'word': "you're", 'start': 124.141, 'end': 124.401, 'score': 0.551},
#     {'word': 'a', 'start': 124.441, 'end': 124.501, 'score': 0.133},
#     {'word': 'business', 'start': 124.521, 'end': 124.782, 'score': 0.485},
#     {'word': 'owner,', 'start': 124.842, 'end': 125.062, 'score': 0.844},
#     {'word': 'definitely', 'start': 125.082, 'end': 125.422, 'score': 0.501},
#     {'word': 'you', 'start': 125.462, 'end': 125.542, 'score': 0.996},
#     {'word': 'have', 'start': 125.582, 'end': 125.722, 'score': 0.898},
#     {'word': 'a', 'start': 125.762, 'end': 125.782, 'score': 0.98},
#     {'word': 'credit', 'start': 125.842, 'end': 126.103, 'score': 0.55},
#     {'word': 'card', 'start': 126.143, 'end': 126.263, 'score': 0.728},
#     {'word': 'machine,', 'start': 126.283, 'end': 126.583, 'score': 0.386},
#     {'word': 'right?', 'start': 126.623, 'end': 126.863, 'score': 0.424}]},
#   {'start': 127.304,
#    'end': 134.75,
#    'text': "So every time your client would, let's say, swipe their cards, debit or credit cards, you will pay 1.5 to 3.5% of the processing fees.",
#    'words': [{'word': 'So', 'start': 127.304, 'end': 127.424, 'score': 0.85},
#     {'word': 'every', 'start': 127.484, 'end': 127.664, 'score': 0.987},
#     {'word': 'time', 'start': 127.704, 'end': 127.844, 'score': 0.874},
#     {'word': 'your', 'start': 127.884, 'end': 128.084, 'score': 0.738},
#     {'word': 'client', 'start': 128.124, 'end': 128.565, 'score': 0.582},
#     {'word': 'would,', 'start': 129.385, 'end': 130.166, 'score': 0.694},
#     {'word': "let's", 'start': 130.246, 'end': 130.446, 'score': 0.743},
#     {'word': 'say,', 'start': 130.466, 'end': 130.646, 'score': 0.679},
#     {'word': 'swipe', 'start': 130.686, 'end': 130.967, 'score': 0.797},
#     {'word': 'their', 'start': 130.987, 'end': 131.127, 'score': 0.538},
#     {'word': 'cards,', 'start': 131.207, 'end': 131.467, 'score': 0.832},
#     {'word': 'debit', 'start': 131.547, 'end': 131.827, 'score': 0.872},
#     {'word': 'or', 'start': 131.887, 'end': 131.967, 'score': 0.905},
#     {'word': 'credit', 'start': 132.047, 'end': 132.348, 'score': 0.917},
#     {'word': 'cards,', 'start': 132.388, 'end': 132.608, 'score': 0.831},
#     {'word': 'you', 'start': 132.648, 'end': 132.748, 'score': 0.971},
#     {'word': 'will', 'start': 132.768, 'end': 132.928, 'score': 0.828},
#     {'word': 'pay', 'start': 132.988, 'end': 133.128, 'score': 0.974},
#     {'word': '1.5'},
#     {'word': 'to', 'start': 133.168, 'end': 133.409, 'score': 0.694},
#     {'word': '3.5%'},
#     {'word': 'of', 'start': 133.549, 'end': 133.929, 'score': 0.528},
#     {'word': 'the', 'start': 133.969, 'end': 134.069, 'score': 0.853},
#     {'word': 'processing', 'start': 134.129, 'end': 134.55, 'score': 0.529},
#     {'word': 'fees.', 'start': 134.59, 'end': 134.75, 'score': 0.539}]},
#   {'start': 137.647,
#    'end': 138.227,
#    'text': ' Okay?',
#    'words': [{'word': 'Okay?',
#      'start': 137.647,
#      'end': 138.227,
#      'score': 0.532}]},
#   {'start': 138.707,
#    'end': 143.251,
#    'text': "So with this information, Patel, it's zero processing, meaning you will save thousands of dollars, sir.",
#    'words': [{'word': 'So', 'start': 138.707, 'end': 138.867, 'score': 0.52},
#     {'word': 'with', 'start': 138.928, 'end': 139.088, 'score': 0.847},
#     {'word': 'this', 'start': 139.168, 'end': 139.348, 'score': 0.925},
#     {'word': 'information,', 'start': 139.488, 'end': 140.108, 'score': 0.782},
#     {'word': 'Patel,', 'start': 140.188, 'end': 140.589, 'score': 0.69},
#     {'word': "it's", 'start': 140.769, 'end': 140.869, 'score': 0.514},
#     {'word': 'zero', 'start': 140.929, 'end': 141.189, 'score': 0.835},
#     {'word': 'processing,', 'start': 141.209, 'end': 141.69, 'score': 0.918},
#     {'word': 'meaning', 'start': 141.73, 'end': 141.93, 'score': 0.281},
#     {'word': 'you', 'start': 141.97, 'end': 142.03, 'score': 0.468},
#     {'word': 'will', 'start': 142.05, 'end': 142.19, 'score': 0.73},
#     {'word': 'save', 'start': 142.21, 'end': 142.35, 'score': 0.436},
#     {'word': 'thousands', 'start': 142.37, 'end': 142.67, 'score': 0.747},
#     {'word': 'of', 'start': 142.73, 'end': 142.77, 'score': 0.788},
#     {'word': 'dollars,', 'start': 142.81, 'end': 143.091, 'score': 0.837},
#     {'word': 'sir.', 'start': 143.111, 'end': 143.251, 'score': 0.543}]},
#   {'start': 143.291,
#    'end': 150.656,
#    'text': 'And my colleague will try to reach you back tomorrow for 6 p.m., and he will give you, you know, detailed information, how it works, all the information, sir.',
#    'words': [{'word': 'And', 'start': 143.291, 'end': 143.391, 'score': 0.783},
#     {'word': 'my', 'start': 143.451, 'end': 143.591, 'score': 0.976},
#     {'word': 'colleague', 'start': 143.671, 'end': 143.991, 'score': 0.802},
#     {'word': 'will', 'start': 144.011, 'end': 144.171, 'score': 0.936},
#     {'word': 'try', 'start': 144.211, 'end': 144.351, 'score': 0.984},
#     {'word': 'to', 'start': 144.391, 'end': 144.471, 'score': 0.539},
#     {'word': 'reach', 'start': 144.492, 'end': 144.652, 'score': 0.602},
#     {'word': 'you', 'start': 144.672, 'end': 144.772, 'score': 0.975},
#     {'word': 'back', 'start': 144.812, 'end': 144.932, 'score': 0.944},
#     {'word': 'tomorrow', 'start': 144.972, 'end': 145.292, 'score': 0.864},
#     {'word': 'for', 'start': 145.332, 'end': 145.452, 'score': 0.627},
#     {'word': '6'},
#     {'word': 'p.m.,', 'start': 145.712, 'end': 145.953, 'score': 0.766},
#     {'word': 'and', 'start': 146.213, 'end': 146.293, 'score': 0.943},
#     {'word': 'he', 'start': 146.333, 'end': 146.413, 'score': 0.976},
#     {'word': 'will', 'start': 146.453, 'end': 146.653, 'score': 0.888},
#     {'word': 'give', 'start': 146.753, 'end': 146.913, 'score': 0.941},
#     {'word': 'you,', 'start': 146.953, 'end': 147.133, 'score': 0.84},
#     {'word': 'you', 'start': 147.454, 'end': 147.534, 'score': 0.879},
#     {'word': 'know,', 'start': 147.574, 'end': 147.714, 'score': 0.93},
#     {'word': 'detailed', 'start': 147.934, 'end': 148.274, 'score': 0.654},
#     {'word': 'information,', 'start': 148.334, 'end': 148.835, 'score': 0.795},
#     {'word': 'how', 'start': 148.935, 'end': 149.055, 'score': 0.998},
#     {'word': 'it', 'start': 149.135, 'end': 149.195, 'score': 0.979},
#     {'word': 'works,', 'start': 149.255, 'end': 149.535, 'score': 0.85},
#     {'word': 'all', 'start': 149.615, 'end': 149.735, 'score': 0.828},
#     {'word': 'the', 'start': 149.775, 'end': 149.875, 'score': 0.908},
#     {'word': 'information,', 'start': 149.955, 'end': 150.456, 'score': 0.914},
#     {'word': 'sir.', 'start': 150.476, 'end': 150.656, 'score': 0.682}]},
#   {'start': 150.676,
#    'end': 152.537,
#    'text': "So we're not here to change any of what you have.",
#    'words': [{'word': 'So', 'start': 150.676, 'end': 150.816, 'score': 0.645},
#     {'word': "we're", 'start': 150.856, 'end': 151.056, 'score': 0.463},
#     {'word': 'not', 'start': 151.076, 'end': 151.216, 'score': 0.605},
#     {'word': 'here', 'start': 151.236, 'end': 151.356, 'score': 0.298},
#     {'word': 'to', 'start': 151.396, 'end': 151.476, 'score': 0.723},
#     {'word': 'change', 'start': 151.517, 'end': 151.777, 'score': 0.826},
#     {'word': 'any', 'start': 151.877, 'end': 152.017, 'score': 0.906},
#     {'word': 'of', 'start': 152.057, 'end': 152.117, 'score': 0.714},
#     {'word': 'what', 'start': 152.137, 'end': 152.277, 'score': 0.888},
#     {'word': 'you', 'start': 152.297, 'end': 152.397, 'score': 0.923},
#     {'word': 'have.', 'start': 152.417, 'end': 152.537, 'score': 0.852}]},
#   {'start': 152.777,
#    'end': 153.018,
#    'text': 'Okay.',
#    'words': [{'word': 'Okay.',
#      'start': 152.777,
#      'end': 153.018,
#      'score': 0.418}]},
#   {'start': 153.038,
#    'end': 154.419,
#    'text': 'Just a good perspective.',
#    'words': [{'word': 'Just',
#      'start': 153.038,
#      'end': 153.178,
#      'score': 0.365},
#     {'word': 'a', 'start': 153.238, 'end': 153.338, 'score': 0.486},
#     {'word': 'good', 'start': 153.678, 'end': 153.778, 'score': 0.35},
#     {'word': 'perspective.',
#      'start': 153.798,
#      'end': 154.419,
#      'score': 0.482}]},
#   {'start': 154.939,
#    'end': 160.483,
#    'text': 'So tomorrow, 6 p.m., sir, and what would be the best business name that we can put here, sir, in my data?',
#    'words': [{'word': 'So', 'start': 154.939, 'end': 155.099, 'score': 0.848},
#     {'word': 'tomorrow,', 'start': 155.159, 'end': 155.559, 'score': 0.921},
#     {'word': '6'},
#     {'word': 'p.m.,', 'start': 155.84, 'end': 156.08, 'score': 0.805},
#     {'word': 'sir,', 'start': 156.1, 'end': 156.26, 'score': 0.463},
#     {'word': 'and', 'start': 156.32, 'end': 156.7, 'score': 0.655},
#     {'word': 'what', 'start': 156.9, 'end': 157.06, 'score': 0.799},
#     {'word': 'would', 'start': 157.08, 'end': 157.261, 'score': 0.89},
#     {'word': 'be', 'start': 157.281, 'end': 157.381, 'score': 0.885},
#     {'word': 'the', 'start': 157.781, 'end': 157.881, 'score': 0.948},
#     {'word': 'best', 'start': 157.941, 'end': 158.181, 'score': 0.924},
#     {'word': 'business', 'start': 158.441, 'end': 158.702, 'score': 0.641},
#     {'word': 'name', 'start': 158.742, 'end': 158.882, 'score': 0.866},
#     {'word': 'that', 'start': 158.902, 'end': 159.062, 'score': 0.799},
#     {'word': 'we', 'start': 159.142, 'end': 159.242, 'score': 0.923},
#     {'word': 'can', 'start': 159.262, 'end': 159.402, 'score': 0.897},
#     {'word': 'put', 'start': 159.482, 'end': 159.662, 'score': 0.902},
#     {'word': 'here,', 'start': 159.682, 'end': 159.822, 'score': 0.436},
#     {'word': 'sir,', 'start': 159.842, 'end': 159.983, 'score': 0.564},
#     {'word': 'in', 'start': 160.003, 'end': 160.083, 'score': 0.456},
#     {'word': 'my', 'start': 160.103, 'end': 160.203, 'score': 0.826},
#     {'word': 'data?', 'start': 160.223, 'end': 160.483, 'score': 0.917}]},
#   {'start': 161.57,
#    'end': 166.753,
#    'text': " Yeah, so, uh, so I don't have, like, my business is, like, Amazon selling, so it's not Amazon.",
#    'words': [{'word': 'Yeah,', 'start': 161.57, 'end': 161.89, 'score': 0.604},
#     {'word': 'so,', 'start': 161.95, 'end': 162.29, 'score': 0.758},
#     {'word': 'uh,', 'start': 162.571, 'end': 162.691, 'score': 0.392},
#     {'word': 'so', 'start': 162.751, 'end': 162.931, 'score': 0.863},
#     {'word': 'I', 'start': 163.031, 'end': 163.071, 'score': 0.997},
#     {'word': "don't", 'start': 163.111, 'end': 163.291, 'score': 0.772},
#     {'word': 'have,', 'start': 163.311, 'end': 163.391, 'score': 0.002},
#     {'word': 'like,', 'start': 163.511, 'end': 163.691, 'score': 0.628},
#     {'word': 'my', 'start': 163.771, 'end': 163.911, 'score': 0.942},
#     {'word': 'business', 'start': 163.951, 'end': 164.351, 'score': 0.412},
#     {'word': 'is,', 'start': 164.411, 'end': 164.532, 'score': 0.593},
#     {'word': 'like,', 'start': 164.552, 'end': 164.712, 'score': 0.477},
#     {'word': 'Amazon', 'start': 164.752, 'end': 165.092, 'score': 0.505},
#     {'word': 'selling,', 'start': 165.132, 'end': 165.472, 'score': 0.872},
#     {'word': 'so', 'start': 165.512, 'end': 165.572, 'score': 0.238},
#     {'word': "it's", 'start': 165.592, 'end': 165.732, 'score': 0.381},
#     {'word': 'not', 'start': 165.792, 'end': 165.952, 'score': 0.769},
#     {'word': 'Amazon.', 'start': 166.012, 'end': 166.753, 'score': 0.721}]},
#   {'start': 166.833,
#    'end': 167.233,
#    'text': 'Oh, wow.',
#    'words': [{'word': 'Oh,', 'start': 166.833, 'end': 167.013, 'score': 0.51},
#     {'word': 'wow.', 'start': 167.033, 'end': 167.233, 'score': 0.441}]},
#   {'start': 167.333,
#    'end': 169.194,
#    'text': 'Amazon, Amazon, Amazon.',
#    'words': [{'word': 'Amazon,',
#      'start': 167.333,
#      'end': 167.733,
#      'score': 0.78},
#     {'word': 'Amazon,', 'start': 167.873, 'end': 168.413, 'score': 0.729},
#     {'word': 'Amazon.', 'start': 168.834, 'end': 169.194, 'score': 0.53}]},
#   {'start': 169.214,
#    'end': 170.575,
#    'text': 'So you take credit cards there.',
#    'words': [{'word': 'So', 'start': 169.214, 'end': 169.334, 'score': 0.654},
#     {'word': 'you', 'start': 169.354, 'end': 169.454, 'score': 0.03},
#     {'word': 'take', 'start': 169.474, 'end': 169.674, 'score': 0.427},
#     {'word': 'credit', 'start': 169.714, 'end': 169.974, 'score': 0.487},
#     {'word': 'cards', 'start': 170.054, 'end': 170.274, 'score': 0.523},
#     {'word': 'there.', 'start': 170.294, 'end': 170.575, 'score': 0.603}]},
#   {'start': 170.675,
#    'end': 172.335,
#    'text': 'Yeah, you take credit cards there as well, sir.',
#    'words': [{'word': 'Yeah,',
#      'start': 170.675,
#      'end': 170.835,
#      'score': 0.526},
#     {'word': 'you', 'start': 170.875, 'end': 170.975, 'score': 0.328},
#     {'word': 'take', 'start': 171.015, 'end': 171.155, 'score': 0.457},
#     {'word': 'credit', 'start': 171.175, 'end': 171.435, 'score': 0.429},
#     {'word': 'cards', 'start': 171.455, 'end': 171.595, 'score': 0.295},
#     {'word': 'there', 'start': 171.615, 'end': 171.795, 'score': 0.426},
#     {'word': 'as', 'start': 171.835, 'end': 171.915, 'score': 0.769},
#     {'word': 'well,', 'start': 171.975, 'end': 172.135, 'score': 0.963},
#     {'word': 'sir.', 'start': 172.175, 'end': 172.335, 'score': 0.812}]},
#   {'start': 172.395,
#    'end': 174.777,
#    'text': 'I know that, because my friends are in Amazon.',
#    'words': [{'word': 'I', 'start': 172.395, 'end': 172.455, 'score': 0.805},
#     {'word': 'know', 'start': 172.495, 'end': 172.636, 'score': 0.895},
#     {'word': 'that,', 'start': 172.656, 'end': 172.876, 'score': 0.807},
#     {'word': 'because', 'start': 172.936, 'end': 173.416, 'score': 0.326},
#     {'word': 'my', 'start': 173.456, 'end': 173.576, 'score': 0.967},
#     {'word': 'friends', 'start': 173.616, 'end': 173.816, 'score': 0.288},
#     {'word': 'are', 'start': 174.056, 'end': 174.156, 'score': 0.513},
#     {'word': 'in', 'start': 174.216, 'end': 174.316, 'score': 0.583},
#     {'word': 'Amazon.', 'start': 174.336, 'end': 174.777, 'score': 0.748}]},
#   {'start': 174.877,
#    'end': 178.619,
#    'text': "But it's not, like, I don't have, like, uh, like, machine that they can swipe.",
#    'words': [{'word': 'But', 'start': 174.877, 'end': 175.017, 'score': 0.88},
#     {'word': "it's", 'start': 175.077, 'end': 175.177, 'score': 0.734},
#     {'word': 'not,', 'start': 175.237, 'end': 175.397, 'score': 0.823},
#     {'word': 'like,', 'start': 175.457, 'end': 175.637, 'score': 0.879},
#     {'word': 'I', 'start': 175.757, 'end': 175.797, 'score': 0.999},
#     {'word': "don't", 'start': 175.837, 'end': 175.997, 'score': 0.838},
#     {'word': 'have,', 'start': 176.037, 'end': 176.157, 'score': 0.426},
#     {'word': 'like,', 'start': 176.197, 'end': 176.377, 'score': 0.876},
#     {'word': 'uh,', 'start': 176.778, 'end': 176.898, 'score': 0.634},
#     {'word': 'like,', 'start': 176.978, 'end': 177.118, 'score': 0.941},
#     {'word': 'machine', 'start': 177.178, 'end': 177.598, 'score': 0.734},
#     {'word': 'that', 'start': 177.638, 'end': 177.838, 'score': 0.772},
#     {'word': 'they', 'start': 177.898, 'end': 178.018, 'score': 0.404},
#     {'word': 'can', 'start': 178.058, 'end': 178.238, 'score': 0.632},
#     {'word': 'swipe.', 'start': 178.278, 'end': 178.619, 'score': 0.748}]},
#   {'start': 178.979,
#    'end': 180.98,
#    'text': "It's just Amazon, Amazon platform they use.",
#    'words': [{'word': "It's",
#      'start': 178.979,
#      'end': 179.079,
#      'score': 0.233},
#     {'word': 'just', 'start': 179.099, 'end': 179.299, 'score': 0.358},
#     {'word': 'Amazon,', 'start': 179.399, 'end': 179.739, 'score': 0.743},
#     {'word': 'Amazon', 'start': 179.799, 'end': 180.099, 'score': 0.405},
#     {'word': 'platform', 'start': 180.159, 'end': 180.539, 'score': 0.441},
#     {'word': 'they', 'start': 180.559, 'end': 180.72, 'score': 0.615},
#     {'word': 'use.', 'start': 180.82, 'end': 180.98, 'score': 0.696}]},
#   {'start': 181.52,
#    'end': 183.821,
#    'text': 'So there is no, like, charges on me.',
#    'words': [{'word': 'So', 'start': 181.52, 'end': 181.64, 'score': 0.578},
#     {'word': 'there', 'start': 181.66, 'end': 181.86, 'score': 0.357},
#     {'word': 'is', 'start': 181.92, 'end': 182.06, 'score': 0.613},
#     {'word': 'no,', 'start': 182.14, 'end': 182.42, 'score': 0.907},
#     {'word': 'like,', 'start': 182.46, 'end': 182.641, 'score': 0.772},
#     {'word': 'charges', 'start': 183.021, 'end': 183.401, 'score': 0.579},
#     {'word': 'on', 'start': 183.461, 'end': 183.581, 'score': 0.895},
#     {'word': 'me.', 'start': 183.641, 'end': 183.821, 'score': 0.786}]},
#   {'start': 184.581,
#    'end': 186.122,
#    'text': 'Yeah.',
#    'words': [{'word': 'Yeah.',
#      'start': 184.581,
#      'end': 186.122,
#      'score': 0.77}]},
#   {'start': 186.342,
#    'end': 189.644,
#    'text': 'So with this one, Mr. Patel, uh, this is just a guesstimate.',
#    'words': [{'word': 'So', 'start': 186.342, 'end': 186.542, 'score': 0.882},
#     {'word': 'with', 'start': 186.703, 'end': 186.883, 'score': 0.804},
#     {'word': 'this', 'start': 186.923, 'end': 187.083, 'score': 0.565},
#     {'word': 'one,', 'start': 187.223, 'end': 187.343, 'score': 0.817},
#     {'word': 'Mr.', 'start': 187.383, 'end': 187.643, 'score': 0.58},
#     {'word': 'Patel,', 'start': 187.683, 'end': 188.063, 'score': 0.818},
#     {'word': 'uh,', 'start': 188.523, 'end': 188.603, 'score': 0.419},
# ...
#   {'word': 'good', 'start': 259.31, 'end': 259.45, 'score': 0.684},
#   {'word': 'in', 'start': 259.49, 'end': 259.57, 'score': 0.714},
#   {'word': 'that', 'start': 259.59, 'end': 259.75, 'score': 0.522},
#   {'word': 'as', 'start': 259.79, 'end': 259.89, 'score': 0.903},
#   {'word': 'well.', 'start': 259.95, 'end': 260.13, 'score': 0.96},
#   {'word': 'Okay,', 'start': 260.19, 'end': 260.451, 'score': 0.647},
#   {'word': 'so', 'start': 260.471, 'end': 260.771, 'score': 0.484},
#   {'word': "you're", 'start': 260.791, 'end': 261.031, 'score': 0.63},
#   {'word': 'one', 'start': 261.151, 'end': 261.251, 'score': 0.867},
#   {'word': 'of', 'start': 261.271, 'end': 261.331, 'score': 0.818},
#   {'word': 'those', 'start': 261.371, 'end': 261.531, 'score': 0.935},
#   {'word': 'teams.', 'start': 261.591, 'end': 261.852, 'score': 0.764},
#   {'word': 'So', 'start': 262.572, 'end': 263.213, 'score': 0.531},
#   {'word': 'how', 'start': 264.434, 'end': 264.534, 'score': 0.993},
#   {'word': 'many', 'start': 264.574, 'end': 264.734, 'score': 0.883},
#   {'word': 'years', 'start': 264.754, 'end': 264.994, 'score': 0.775},
#   {'word': 'are', 'start': 265.334, 'end': 265.414, 'score': 0.94},
#   {'word': 'you', 'start': 265.454, 'end': 265.575, 'score': 0.837},
#   {'word': 'with', 'start': 265.615, 'end': 265.795, 'score': 0.932},
#   {'word': 'Amazon,', 'start': 266.195, 'end': 266.575, 'score': 0.909},
#   {'word': 'sir,', 'start': 266.595, 'end': 266.735, 'score': 0.569},
#   {'word': 'if', 'start': 266.776, 'end': 266.836, 'score': 0.982},
#   {'word': 'I', 'start': 266.916, 'end': 266.956, 'score': 0.989},
#   {'word': 'may', 'start': 266.996, 'end': 267.136, 'score': 0.955},
#   {'word': 'ask?', 'start': 267.176, 'end': 267.316, 'score': 0.714},
#   {'word': "You've", 'start': 267.656, 'end': 267.776, 'score': 0.306},
#   {'word': 'been', 'start': 267.796, 'end': 267.916, 'score': 0.475},
#   {'word': 'doing', 'start': 267.936, 'end': 268.137, 'score': 0.8},
#   {'word': 'Amazon?', 'start': 268.177, 'end': 268.517, 'score': 0.726},
#   {'word': 'Uh,', 'start': 269.525, 'end': 269.765, 'score': 0.444},
#   {'word': "it's", 'start': 269.825, 'end': 270.045, 'score': 0.378},
#   {'word': 'been', 'start': 270.225, 'end': 270.745, 'score': 0.766},
#   {'word': 'one', 'start': 271.406, 'end': 271.586, 'score': 0.763},
#   {'word': 'more', 'start': 271.786, 'end': 271.986, 'score': 0.924},
#   {'word': 'than', 'start': 272.026, 'end': 272.186, 'score': 0.944},
#   {'word': 'one', 'start': 272.326, 'end': 272.426, 'score': 0.816},
#   {'word': 'and', 'start': 272.446, 'end': 272.506, 'score': 0.001},
#   {'word': 'a', 'start': 272.526, 'end': 272.546, 'score': 0.004},
#   {'word': 'half', 'start': 272.566, 'end': 272.806, 'score': 0.882},
#   {'word': 'years,', 'start': 272.846, 'end': 273.086, 'score': 0.53},
#   {'word': 'something', 'start': 273.246, 'end': 273.586, 'score': 0.859},
#   {'word': 'like', 'start': 273.626, 'end': 273.766, 'score': 0.938},
#   {'word': 'that.', 'start': 273.806, 'end': 274.787, 'score': 0.362},
#   {'word': 'Wow.', 'start': 275.267, 'end': 275.447, 'score': 0.424},
#   {'word': 'Wow.', 'start': 275.487, 'end': 276.307, 'score': 0.704},
#   {'word': 'If', 'start': 276.387, 'end': 276.487, 'score': 0.652},
#   {'word': 'you', 'start': 276.507, 'end': 276.627, 'score': 0.399},
#   {'word': 'try', 'start': 276.667, 'end': 276.887, 'score': 0.648},
#   {'word': 'to', 'start': 276.927, 'end': 277.047, 'score': 0.835},
#   {'word': 'decide', 'start': 277.087, 'end': 277.407, 'score': 0.81},
#   {'word': 'to,', 'start': 277.448, 'end': 277.648, 'score': 0.94},
#   {'word': 'to', 'start': 277.808, 'end': 277.988, 'score': 0.988},
#   {'word': 'shut', 'start': 278.088, 'end': 278.288, 'score': 0.861},
#   {'word': 'it', 'start': 278.308, 'end': 278.388, 'score': 0.904},
#   {'word': 'off', 'start': 278.508, 'end': 278.668, 'score': 0.882},
#   {'word': 'one', 'start': 278.768, 'end': 278.868, 'score': 0.713},
#   {'word': 'of', 'start': 278.908, 'end': 278.988, 'score': 0.734},
#   {'word': 'these', 'start': 279.028, 'end': 279.168, 'score': 0.794},
#   {'word': 'days,', 'start': 279.208, 'end': 279.428, 'score': 0.821},
#   {'word': 'cause', 'start': 279.468, 'end': 279.728, 'score': 0.568},
#   {'word': "you're", 'start': 280.068, 'end': 280.268, 'score': 0.876},
#   {'word': 'one', 'start': 280.328, 'end': 280.408, 'score': 0.901},
#   {'word': 'of', 'start': 280.448, 'end': 280.488, 'score': 0.998},
#   {'word': 'the', 'start': 280.528, 'end': 280.629, 'score': 0.847},
#   {'word': 'veterans', 'start': 280.649, 'end': 281.029, 'score': 0.646},
#   {'word': 'or', 'start': 281.069, 'end': 281.149, 'score': 0.466},
#   {'word': 'if', 'start': 281.189, 'end': 281.289, 'score': 0.548},
#   {'word': "you're", 'start': 281.589, 'end': 281.809, 'score': 0.556},
#   {'word': 'more', 'start': 282.109, 'end': 282.269, 'score': 0.881},
#   {'word': 'than', 'start': 282.289, 'end': 282.429, 'score': 0.68},
#   {'word': 'a', 'start': 282.489, 'end': 282.529, 'score': 0.506},
#   {'word': 'year,', 'start': 282.569, 'end': 282.849, 'score': 0.34},
#   {'word': "you're", 'start': 282.929, 'end': 283.149, 'score': 0.891},
#   {'word': 'one', 'start': 283.209, 'end': 283.289, 'score': 0.839},
#   {'word': 'of', 'start': 283.329, 'end': 283.369, 'score': 0.998},
#   {'word': 'those', 'start': 283.429, 'end': 283.589, 'score': 0.833},
#   {'word': 'veterans', 'start': 283.689, 'end': 284.11, 'score': 0.833},
#   {'word': 'who', 'start': 284.15, 'end': 284.53, 'score': 0.655},
#   {'word': 'buy', 'start': 284.63, 'end': 284.81, 'score': 0.811},
#   {'word': 'and', 'start': 284.87, 'end': 284.93, 'score': 0.216},
#   {'word': 'sell', 'start': 285.05, 'end': 285.39, 'score': 0.902},
#   {'word': 'in', 'start': 285.87, 'end': 285.95, 'score': 0.937},
#   {'word': 'terms', 'start': 285.97, 'end': 286.39, 'score': 0.676},
#   {'word': 'of.', 'start': 287.111, 'end': 287.411, 'score': 0.353},
#   {'word': 'But', 'start': 288.511, 'end': 288.651, 'score': 0.907},
#   {'word': 'the', 'start': 288.691, 'end': 288.791, 'score': 0.868},
#   {'word': 'thing', 'start': 288.811, 'end': 289.031, 'score': 0.921},
#   {'word': 'is', 'start': 289.131, 'end': 289.231, 'score': 0.824},
#   {'word': 'I', 'start': 289.291, 'end': 289.351, 'score': 0.675},
#   {'word': 'was', 'start': 289.371, 'end': 289.511, 'score': 0.791},
#   {'word': 'doing', 'start': 289.531, 'end': 289.771, 'score': 0.865},
#   {'word': 'it', 'start': 289.811, 'end': 289.891, 'score': 0.914},
#   {'word': 'at', 'start': 289.971, 'end': 290.031, 'score': 0.972},
#   {'word': 'part', 'start': 290.131, 'end': 290.372, 'score': 0.891},
#   {'word': 'time', 'start': 290.392, 'end': 290.672, 'score': 0.742},
#   {'word': 'and', 'start': 290.912, 'end': 291.072, 'score': 0.806},
#   {'word': 'I', 'start': 291.512, 'end': 291.572, 'score': 0.697},
#   {'word': 'was', 'start': 291.612, 'end': 291.732, 'score': 0.993},
#   {'word': 'not', 'start': 291.792, 'end': 291.952, 'score': 0.825},
#   {'word': 'really', 'start': 291.972, 'end': 292.252, 'score': 0.669},
#   {'word': 'focused', 'start': 292.292, 'end': 292.712, 'score': 0.583},
#   {'word': 'on', 'start': 292.772, 'end': 292.852, 'score': 0.854},
#   {'word': 'it.', 'start': 292.912, 'end': 293.012, 'score': 0.845},
#   {'word': 'And', 'start': 293.413, 'end': 293.493, 'score': 0.831},
#   {'word': 'I', 'start': 293.533, 'end': 293.613, 'score': 0.805},
#   {'word': 'tried', 'start': 293.673, 'end': 293.993, 'score': 0.803},
#   {'word': 'to', 'start': 294.053, 'end': 294.233, 'score': 0.898},
#   {'word': 'hire', 'start': 294.313, 'end': 294.633, 'score': 0.759},
#   {'word': 'some', 'start': 294.673, 'end': 294.853, 'score': 0.372},
#   {'word': 'other', 'start': 294.973, 'end': 295.173, 'score': 0.862},
#   {'word': 'party,', 'start': 295.213, 'end': 295.573, 'score': 0.893},
#   {'word': 'but', 'start': 295.613, 'end': 295.773, 'score': 0.938},
#   {'word': 'they', 'start': 295.973, 'end': 296.513, 'score': 0.611},
#   {'word': 'have', 'start': 296.614, 'end': 297.314, 'score': 0.722},
#   {'word': 'not', 'start': 297.474, 'end': 297.674, 'score': 0.844},
#   {'word': 'good.', 'start': 297.814, 'end': 298.034, 'score': 0.77},
#   {'word': 'So', 'start': 298.683, 'end': 298.723, 'score': 0.003},
#   {'word': 'I', 'start': 298.743, 'end': 298.823, 'score': 0.582},
#   {'word': 'was', 'start': 298.843, 'end': 298.983, 'score': 0.601},
#   {'word': 'just', 'start': 299.003, 'end': 299.163, 'score': 0.42},
#   {'word': 'losing', 'start': 299.243, 'end': 299.584, 'score': 0.854},
#   {'word': 'the', 'start': 299.644, 'end': 299.744, 'score': 0.929},
#   {'word': 'money.', 'start': 299.784, 'end': 300.064, 'score': 0.794},
#   {'word': "That's", 'start': 300.644, 'end': 300.844, 'score': 0.556},
#   {'word': 'why', 'start': 300.924, 'end': 301.405, 'score': 0.586},
#   {'word': 'right', 'start': 301.545, 'end': 301.745, 'score': 0.437},
#   {'word': 'now', 'start': 301.765, 'end': 301.925, 'score': 0.725},
#   {'word': "it's", 'start': 301.985, 'end': 302.225, 'score': 0.459},
#   {'word': 'barely', 'start': 302.425, 'end': 302.806, 'score': 0.754},
#   {'word': 'selling', 'start': 302.846, 'end': 303.166, 'score': 0.904},
#   {'word': 'one', 'start': 303.326, 'end': 303.466, 'score': 0.575},
#   {'word': 'or', 'start': 303.526, 'end': 303.686, 'score': 0.532},
#   {'word': 'zero', 'start': 303.866, 'end': 304.267, 'score': 0.73},
#   {'word': 'a', 'start': 304.367, 'end': 304.427, 'score': 0.555},
#   {'word': 'day.', 'start': 304.467, 'end': 304.687, 'score': 0.828},
#   {'word': 'So', 'start': 305.567, 'end': 305.788, 'score': 0.71},
#   {'word': "that's", 'start': 305.828, 'end': 306.008, 'score': 0.426},
#   {'word': 'why.', 'start': 306.068, 'end': 306.288, 'score': 0.479},
#   {'word': "There's", 'start': 306.328, 'end': 306.508, 'score': 0.345},
#   {'word': 'a', 'start': 306.528, 'end': 306.568, 'score': 0.464},
#   {'word': 'lot', 'start': 306.608, 'end': 306.728, 'score': 0.985},
#   {'word': 'of', 'start': 306.748, 'end': 306.808, 'score': 0.691},
#   {'word': 'competition,', 'start': 306.848, 'end': 307.409, 'score': 0.816},
#   {'word': 'right?', 'start': 307.469, 'end': 307.669, 'score': 0.456},
#   {'word': "There's", 'start': 307.989, 'end': 308.209, 'score': 0.714},
#   {'word': 'a', 'start': 308.229, 'end': 308.249, 'score': 0.98},
#   {'word': 'lot', 'start': 308.289, 'end': 308.449, 'score': 0.901},
#   {'word': 'of', 'start': 308.469, 'end': 308.529, 'score': 0.734},
#   {'word': 'competition', 'start': 308.569, 'end': 309.89, 'score': 0.728},
#   {'word': 'and', 'start': 310.23, 'end': 310.35, 'score': 0.871},
#   {'word': 'some,', 'start': 310.431, 'end': 310.871, 'score': 0.872},
#   {'word': "let's", 'start': 310.931, 'end': 311.111, 'score': 0.612},
#   {'word': 'say', 'start': 311.131, 'end': 311.271, 'score': 0.675},
#   {'word': "you're", 'start': 311.291, 'end': 311.471, 'score': 0.609},
#   {'word': 'selling', 'start': 311.511, 'end': 311.851, 'score': 0.711},
#   {'word': 'stuff.', 'start': 311.871, 'end': 312.112, 'score': 0.662},
#   {'word': 'This', 'start': 312.172, 'end': 312.312, 'score': 0.908},
#   {'word': 'is', 'start': 312.352, 'end': 312.412, 'score': 0.752},
#   {'word': 'only', 'start': 312.452, 'end': 312.592, 'score': 0.831},
#   {'word': 'an', 'start': 312.612, 'end': 312.672, 'score': 0.678},
#   {'word': 'example.', 'start': 312.712, 'end': 313.132, 'score': 0.929},
#   {'word': 'And', 'start': 313.512, 'end': 313.593, 'score': 0.911},
#   {'word': 'then', 'start': 313.613, 'end': 313.753, 'score': 0.745},
#   {'word': 'you', 'start': 313.773, 'end': 313.853, 'score': 0.99},
#   {'word': 'will', 'start': 313.873, 'end': 314.013, 'score': 0.899},
#   {'word': 'see', 'start': 314.053, 'end': 314.153, 'score': 0.851},
#   {'word': 'online,', 'start': 314.213, 'end': 314.673, 'score': 0.397},
#   {'word': "let's", 'start': 315.114, 'end': 315.294, 'score': 0.682},
#   {'word': 'say', 'start': 315.314, 'end': 315.614, 'score': 0.641},
#   {'word': "you're", 'start': 315.634, 'end': 315.754, 'score': 0.31},
#   {'word': 'selling', 'start': 315.774, 'end': 316.014, 'score': 0.925},
#   {'word': 'it', 'start': 316.054, 'end': 316.114, 'score': 0.969},
#   {'word': 'for', 'start': 316.154, 'end': 316.274, 'score': 0.996},
#   {'word': 'only', 'start': 316.334, 'end': 316.534, 'score': 0.78},
#   {'word': '$5.'},
#   {'word': 'This', 'start': 316.574, 'end': 317.195, 'score': 0.422},
#   {'word': 'is', 'start': 317.335, 'end': 317.435, 'score': 0.7},
#   {'word': 'just', 'start': 317.475, 'end': 317.655, 'score': 0.728},
#   {'word': 'an', 'start': 317.675, 'end': 317.755, 'score': 0.784},
#   {'word': 'example.', 'start': 317.795, 'end': 318.155, 'score': 0.845},
#   {'word': 'And', 'start': 318.195, 'end': 318.256, 'score': 0.981},
#   {'word': 'then', 'start': 318.296, 'end': 318.416, 'score': 0.836},
#   {'word': 'when', 'start': 318.536, 'end': 318.656, 'score': 0.276},
#   {'word': 'you', 'start': 318.676, 'end': 318.736, 'score': 0.344},
#   {'word': 'see', 'start': 318.776, 'end': 318.896, 'score': 0.904},
#   {'word': 'on', 'start': 318.976, 'end': 319.096, 'score': 0.486},
#   {'word': 'Amazon,', 'start': 319.196, 'end': 320.237, 'score': 0.822},
#   {'word': 'your', 'start': 320.257, 'end': 320.397, 'score': 0.831},
#   {'word': 'competitors', 'start': 320.417, 'end': 320.897, 'score': 0.751},
#   {'word': 'are', 'start': 320.957, 'end': 321.037, 'score': 0.613},
#   {'word': 'selling', 'start': 321.057, 'end': 321.337, 'score': 0.938},
#   {'word': 'it', 'start': 321.398, 'end': 321.458, 'score': 0.78},
#   {'word': 'for', 'start': 321.498, 'end': 322.118, 'score': 0.661},
#   {'word': 'only', 'start': 322.218, 'end': 322.458, 'score': 0.505},
#   {'word': '$3.'},
#   {'word': 'Some', 'start': 322.999, 'end': 323.339, 'score': 0.849},
#   {'word': 'people', 'start': 323.359, 'end': 323.579, 'score': 0.927},
#   {'word': 'are', 'start': 323.639, 'end': 323.919, 'score': 0.629},
#   {'word': 'like', 'start': 323.959, 'end': 324.179, 'score': 0.358},
#   {'word': 'that.', 'start': 324.379, 'end': 324.56, 'score': 0.421},
#   {'word': 'You', 'start': 324.6, 'end': 324.7, 'score': 0.968},
#   {'word': 'were', 'start': 324.72, 'end': 324.84, 'score': 0.925},
#   {'word': 'like,', 'start': 324.86, 'end': 325.0, 'score': 0.769},
#   {'word': 'oh', 'start': 325.06, 'end': 325.16, 'score': 0.408},
#   {'word': 'my', 'start': 325.18, 'end': 325.26, 'score': 0.778},
#   {'word': 'gosh,', 'start': 325.3, 'end': 325.54, 'score': 0.609},
#   {'word': "I'm", 'start': 325.68, 'end': 325.8, 'score': 0.436},
#   {'word': 'a', 'start': 326.241, 'end': 326.341, 'score': 0.592},
#   {'word': 'bit', 'start': 326.361, 'end': 326.461, 'score': 0.567},
#   {'word': 'higher', 'start': 326.601, 'end': 326.881, 'score': 0.646},
#   {'word': 'for', 'start': 326.901, 'end': 327.021, 'score': 0.772},
#   {'word': '$2'},
#   {'word': 'here.', 'start': 327.081, 'end': 327.181, 'score': 0.125},
#   {'word': 'Sometimes', 'start': 328.683, 'end': 329.023, 'score': 0.921},
#   {'word': 'they', 'start': 329.063, 'end': 329.203, 'score': 0.515},
#   {'word': 'change', 'start': 329.223, 'end': 329.463, 'score': 0.412},
#   {'word': 'that.', 'start': 329.503, 'end': 329.684, 'score': 0.68},
#   {'word': 'So', 'start': 329.744, 'end': 330.084, 'score': 0.71},
#   {'word': "it's", 'start': 330.224, 'end': 330.564, 'score': 0.759},
#   {'word': 'supply', 'start': 330.584, 'end': 330.884, 'score': 0.761},
#   {'word': 'and', 'start': 330.924, 'end': 331.004, 'score': 0.474},
#   {'word': 'demand.', 'start': 331.044, 'end': 331.384, 'score': 0.879},
#   {'word': "It's", 'start': 331.464, 'end': 331.564, 'score': 0.608},
#   {'word': 'a', 'start': 331.624, 'end': 331.664, 'score': 0.358},
#   {'word': 'numbers', 'start': 331.724, 'end': 332.025, 'score': 0.862},
#   {'word': 'game.', 'start': 332.065, 'end': 332.345, 'score': 0.768},
#   {'word': 'And', 'start': 332.945, 'end': 333.045, 'score': 0.892},
#   {'word': 'sometimes', 'start': 333.305, 'end': 333.685, 'score': 0.839},
#   {'word': 'sellers', 'start': 333.725, 'end': 334.006, 'score': 0.519},
#   {'word': 'are', 'start': 334.086, 'end': 334.186, 'score': 0.691},
#   {'word': 'really', 'start': 334.206, 'end': 334.626, 'score': 0.656},
#   ...]}

# %%
diarize_model = whisperx.DiarizationPipeline(use_auth_token="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",
                                             device=device)
# Out:
# config.yaml:   0%|          | 0.00/469 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.91M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/399 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]

# %%
diarize_segments = diarize_model(audio, min_speakers=2, max_speakers=2)

# %%
diarize_segments

# %%
diarize_segments.speaker.unique()

# %%
result = whisperx.assign_word_speakers(diarize_segments, result)
print(diarize_segments)
print(result["segments"]) # segments are now assigned speaker IDs
# Out:
#                                segment label     speaker       start  \
# 0    [ 00:00:00.195 -->  00:00:00.551]     A  SPEAKER_01    0.195246
# 1    [ 00:00:01.740 -->  00:00:02.181]     B  SPEAKER_00    1.740238
# 2    [ 00:00:03.030 -->  00:00:04.813]     C  SPEAKER_01    3.030560
# 3    [ 00:00:06.052 -->  00:00:07.139]     D  SPEAKER_00    6.052632
# 4    [ 00:00:07.376 -->  00:00:07.512]     E  SPEAKER_00    7.376910
# ..                                 ...   ...         ...         ...
# 225  [ 00:09:55.967 -->  00:10:04.983]    HR  SPEAKER_01  595.967742
# 226  [ 00:10:05.967 -->  00:10:07.903]    HS  SPEAKER_00  605.967742
# 227  [ 00:10:06.833 -->  00:10:06.850]    HT  SPEAKER_01  606.833616
# 228  [ 00:10:06.952 -->  00:10:08.752]    HU  SPEAKER_01  606.952462
# 229  [ 00:10:08.480 -->  00:10:08.887]    HV  SPEAKER_00  608.480475
#
#             end  intersection       union
# 0      0.551783   -607.977217  608.594754
# 1      2.181664   -606.347336  607.049762
# 2      4.813243   -603.715757  605.759440
# 3      7.139219   -601.389781  602.737368
# 4      7.512733   -601.016267  601.413090
# ..          ...           ...         ...
# 225  604.983022     -3.545978   12.822258
# 226  607.903226     -0.625774    2.822258
# 227  606.850594     -1.678406    1.956384
# 228  608.752122      0.223122    1.837538
# 229  608.887946      0.261000    0.407470
#
# [230 rows x 7 columns]
# [{'start': 0.236, 'end': 0.496, 'text': ' Hello?', 'words': [{'word': 'Hello?', 'start': 0.236, 'end': 0.496, 'score': 0.699, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 1.817, 'end': 2.117, 'text': 'Hello?', 'words': [{'word': 'Hello?', 'start': 1.817, 'end': 2.117, 'score': 0.744, 'speaker': 'SPEAKER_00'}], 'speaker': 'SPEAKER_00'}, {'start': 3.058, 'end': 4.319, 'text': 'Yes, who am I speaking with?', 'words': [{'word': 'Yes,', 'start': 3.058, 'end': 3.258, 'score': 0.818, 'speaker': 'SPEAKER_01'}, {'word': 'who', 'start': 3.398, 'end': 3.518, 'score': 0.416, 'speaker': 'SPEAKER_01'}, {'word': 'am', 'start': 3.578, 'end': 3.638, 'score': 0.224, 'speaker': 'SPEAKER_01'}, {'word': 'I', 'start': 3.679, 'end': 3.779, 'score': 0.433, 'speaker': 'SPEAKER_01'}, {'word': 'speaking', 'start': 3.799, 'end': 4.139, 'score': 0.866, 'speaker': 'SPEAKER_01'}, {'word': 'with?', 'start': 4.159, 'end': 4.319, 'score': 0.773, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 4.359, 'end': 4.759, 'text': "I'm sorry.", 'words': [{'word': "I'm", 'start': 4.359, 'end': 4.459, 'score': 0.475, 'speaker': 'SPEAKER_01'}, {'word': 'sorry.', 'start': 4.499, 'end': 4.759, 'score': 0.539, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 6.26, 'end': 7.721, 'text': "It's Dhruvin Patel.", 'words': [{'word': "It's", 'start': 6.26, 'end': 6.661, 'score': 0.514, 'speaker': 'SPEAKER_00'}, {'word': 'Dhruvin', 'start': 6.701, 'end': 7.101, 'score': 0.66, 'speaker': 'SPEAKER_00'}, {'word': 'Patel.', 'start': 7.401, 'end': 7.721, 'score': 0.741, 'speaker': 'SPEAKER_00'}], 'speaker': 'SPEAKER_00'}, {'start': 8.962, 'end': 9.683, 'text': 'Come again?', 'words': [{'word': 'Come', 'start': 8.962, 'end': 9.463, 'score': 0.868, 'speaker': 'SPEAKER_01'}, {'word': 'again?', 'start': 9.503, 'end': 9.683, 'score': 0.872, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 9.703, 'end': 10.844, 'text': "I didn't hear you.", 'words': [{'word': 'I', 'start': 9.703, 'end': 9.723, 'score': 0.002, 'speaker': 'SPEAKER_01'}, {'word': "didn't", 'start': 9.923, 'end': 10.103, 'score': 0.562, 'speaker': 'SPEAKER_01'}, {'word': 'hear', 'start': 10.123, 'end': 10.223, 'score': 0.22, 'speaker': 'SPEAKER_01'}, {'word': 'you.', 'start': 10.664, 'end': 10.844, 'score': 0.379, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 10.864, 'end': 11.644, 'text': "You're correct, sir.", 'words': [{'word': "You're", 'start': 10.864, 'end': 11.064, 'score': 0.407, 'speaker': 'SPEAKER_01'}, {'word': 'correct,', 'start': 11.124, 'end': 11.424, 'score': 0.942, 'speaker': 'SPEAKER_01'}, {'word': 'sir.', 'start': 11.444, 'end': 11.644, 'score': 0.64, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 12.985, 'end': 13.566, 'text': 'Mr. Patel?', 'words': [{'word': 'Mr.', 'start': 12.985, 'end': 13.225, 'score': 0.5, 'speaker': 'SPEAKER_00'}, {'word': 'Patel?', 'start': 13.245, 'end': 13.566, 'score': 0.765, 'speaker': 'SPEAKER_00'}], 'speaker': 'SPEAKER_00'}, {'start': 14.526, 'end': 15.007, 'text': 'Oh, Patel.', 'words': [{'word': 'Oh,', 'start': 14.526, 'end': 14.606, 'score': 0.53, 'speaker': 'SPEAKER_01'}, {'word': 'Patel.', 'start': 14.646, 'end': 15.007, 'score': 0.85, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 15.547, 'end': 17.408, 'text': 'Mr. Patel, I believe this number called you.', 'words': [{'word': 'Mr.', 'start': 15.547, 'end': 15.787, 'score': 0.576, 'speaker': 'SPEAKER_01'}, {'word': 'Patel,', 'start': 15.867, 'end': 16.188, 'score': 0.819, 'speaker': 'SPEAKER_01'}, {'word': 'I', 'start': 16.228, 'end': 16.288, 'score': 0.682, 'speaker': 'SPEAKER_01'}, {'word': 'believe', 'start': 16.328, 'end': 16.588, 'score': 0.813, 'speaker': 'SPEAKER_01'}, {'word': 'this', 'start': 16.628, 'end': 16.768, 'score': 0.8, 'speaker': 'SPEAKER_01'}, {'word': 'number', 'start': 16.808, 'end': 17.048, 'score': 0.833, 'speaker': 'SPEAKER_01'}, {'word': 'called', 'start': 17.108, 'end': 17.288, 'score': 0.899 ...

# %%
result
# Out:
# {'segments': [{'start': 0.236,
#    'end': 0.496,
#    'text': ' Hello?',
#    'words': [{'word': 'Hello?',
#      'start': 0.236,
#      'end': 0.496,
#      'score': 0.699,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 1.817,
#    'end': 2.117,
#    'text': 'Hello?',
#    'words': [{'word': 'Hello?',
#      'start': 1.817,
#      'end': 2.117,
#      'score': 0.744,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 3.058,
#    'end': 4.319,
#    'text': 'Yes, who am I speaking with?',
#    'words': [{'word': 'Yes,',
#      'start': 3.058,
#      'end': 3.258,
#      'score': 0.818,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'who',
#      'start': 3.398,
#      'end': 3.518,
#      'score': 0.416,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'am',
#      'start': 3.578,
#      'end': 3.638,
#      'score': 0.224,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'I',
#      'start': 3.679,
#      'end': 3.779,
#      'score': 0.433,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'speaking',
#      'start': 3.799,
#      'end': 4.139,
#      'score': 0.866,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'with?',
#      'start': 4.159,
#      'end': 4.319,
#      'score': 0.773,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 4.359,
#    'end': 4.759,
#    'text': "I'm sorry.",
#    'words': [{'word': "I'm",
#      'start': 4.359,
#      'end': 4.459,
#      'score': 0.475,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sorry.',
#      'start': 4.499,
#      'end': 4.759,
#      'score': 0.539,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 6.26,
#    'end': 7.721,
#    'text': "It's Dhruvin Patel.",
#    'words': [{'word': "It's",
#      'start': 6.26,
#      'end': 6.661,
#      'score': 0.514,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'Dhruvin',
#      'start': 6.701,
#      'end': 7.101,
#      'score': 0.66,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'Patel.',
#      'start': 7.401,
#      'end': 7.721,
#      'score': 0.741,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 8.962,
#    'end': 9.683,
#    'text': 'Come again?',
#    'words': [{'word': 'Come',
#      'start': 8.962,
#      'end': 9.463,
#      'score': 0.868,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'again?',
#      'start': 9.503,
#      'end': 9.683,
#      'score': 0.872,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 9.703,
#    'end': 10.844,
#    'text': "I didn't hear you.",
#    'words': [{'word': 'I',
#      'start': 9.703,
#      'end': 9.723,
#      'score': 0.002,
#      'speaker': 'SPEAKER_01'},
#     {'word': "didn't",
#      'start': 9.923,
#      'end': 10.103,
#      'score': 0.562,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'hear',
#      'start': 10.123,
#      'end': 10.223,
#      'score': 0.22,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you.',
#      'start': 10.664,
#      'end': 10.844,
#      'score': 0.379,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 10.864,
#    'end': 11.644,
#    'text': "You're correct, sir.",
#    'words': [{'word': "You're",
#      'start': 10.864,
#      'end': 11.064,
#      'score': 0.407,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'correct,',
#      'start': 11.124,
#      'end': 11.424,
#      'score': 0.942,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir.',
#      'start': 11.444,
#      'end': 11.644,
#      'score': 0.64,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 12.985,
#    'end': 13.566,
#    'text': 'Mr. Patel?',
#    'words': [{'word': 'Mr.',
#      'start': 12.985,
#      'end': 13.225,
#      'score': 0.5,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'Patel?',
#      'start': 13.245,
#      'end': 13.566,
#      'score': 0.765,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 14.526,
#    'end': 15.007,
#    'text': 'Oh, Patel.',
#    'words': [{'word': 'Oh,',
#      'start': 14.526,
#      'end': 14.606,
#      'score': 0.53,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'Patel.',
#      'start': 14.646,
#      'end': 15.007,
#      'score': 0.85,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 15.547,
#    'end': 17.408,
#    'text': 'Mr. Patel, I believe this number called you.',
#    'words': [{'word': 'Mr.',
#      'start': 15.547,
#      'end': 15.787,
#      'score': 0.576,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'Patel,',
#      'start': 15.867,
#      'end': 16.188,
#      'score': 0.819,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'I',
#      'start': 16.228,
#      'end': 16.288,
#      'score': 0.682,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'believe',
#      'start': 16.328,
#      'end': 16.588,
#      'score': 0.813,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'this',
#      'start': 16.628,
#      'end': 16.768,
#      'score': 0.8,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'number',
#      'start': 16.808,
#      'end': 17.048,
#      'score': 0.833,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'called',
#      'start': 17.108,
#      'end': 17.288,
#      'score': 0.899,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you.',
#      'start': 17.308,
#      'end': 17.408,
#      'score': 0.814,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 17.428,
#    'end': 18.489,
#    'text': "That's why you called us back.",
#    'words': [{'word': "That's",
#      'start': 17.428,
#      'end': 17.609,
#      'score': 0.856,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'why',
#      'start': 17.629,
#      'end': 17.769,
#      'score': 0.719,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 17.789,
#      'end': 17.909,
#      'score': 0.769,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'called',
#      'start': 17.949,
#      'end': 18.149,
#      'score': 0.569,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'us',
#      'start': 18.189,
#      'end': 18.269,
#      'score': 0.544,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'back.',
#      'start': 18.329,
#      'end': 18.489,
#      'score': 0.866,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 18.529,
#    'end': 19.15,
#    'text': 'Is that correct, sir?',
#    'words': [{'word': 'Is',
#      'start': 18.529,
#      'end': 18.589,
#      'score': 0.602,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'that',
#      'start': 18.629,
#      'end': 18.709,
#      'score': 0.516,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'correct,',
#      'start': 18.749,
#      'end': 18.99,
#      'score': 0.738,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir?',
#      'start': 19.01,
#      'end': 19.15,
#      'score': 0.447,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 20.21,
#    'end': 20.751,
#    'text': 'Right, right.',
#    'words': [{'word': 'Right,',
#      'start': 20.21,
#      'end': 20.451,
#      'score': 0.649,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'right.',
#      'start': 20.491,
#      'end': 20.751,
#      'score': 0.635,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 21.251,
#    'end': 22.372,
#    'text': 'Okay, so apologies, sir.',
#    'words': [{'word': 'Okay,',
#      'start': 21.251,
#      'end': 21.411,
#      'score': 0.44,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'so',
#      'start': 21.451,
#      'end': 21.611,
#      'score': 0.917,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'apologies,',
#      'start': 21.652,
#      'end': 22.092,
#      'score': 0.583,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir.',
#      'start': 22.132,
#      'end': 22.372,
#      'score': 0.815,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 22.992,
#    'end': 23.773,
#    'text': 'My name is Nance.',
#    'words': [{'word': 'My',
#      'start': 22.992,
#      'end': 23.113,
#      'score': 0.867,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'name',
#      'start': 23.153,
#      'end': 23.293,
#      'score': 0.812,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 23.333,
#      'end': 23.413,
#      'score': 0.668,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'Nance.',
#      'start': 23.453,
#      'end': 23.773,
#      'score': 0.589,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 23.933,
#    'end': 24.934,
#    'text': "I'm from Aventis Bay.",
#    'words': [{'word': "I'm",
#      'start': 23.933,
#      'end': 24.033,
#      'score': 0.105,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'from',
#      'start': 24.073,
#      'end': 24.213,
#      'score': 0.839,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'Aventis',
#      'start': 24.293,
#      'end': 24.654,
#      'score': 0.614,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'Bay.',
#      'start': 24.754,
#      'end': 24.934,
#      'score': 0.849,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 25.535,
#    'end': 28.838,
#    'text': ' And basically, sir, firstly, I respect what you have, okay?',
#    'words': [{'word': 'And',
#      'start': 25.535,
#      'end': 25.595,
#      'score': 0.485,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'basically,',
#      'start': 25.635,
#      'end': 26.076,
#      'score': 0.822,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir,',
#      'start': 26.116,
#      'end': 26.276,
#      'score': 0.702,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'firstly,',
#      'start': 26.296,
#      'end': 26.736,
#      'score': 0.804,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'I',
#      'start': 27.657,
#      'end': 27.717,
#      'score': 0.86,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'respect',
#      'start': 27.757,
#      'end': 28.097,
#      'score': 0.86,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'what',
#      'start': 28.138,
#      'end': 28.258,
#      'score': 0.875,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 28.278,
#      'end': 28.398,
#      'score': 0.984,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'have,',
#      'start': 28.438,
#      'end': 28.558,
#      'score': 0.942,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'okay?',
#      'start': 28.638,
#      'end': 28.838,
#      'score': 0.585,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 28.858,
#    'end': 32.101,
#    'text': "We're not here to change any of what you have, okay, for starters.",
#    'words': [{'word': "We're",
#      'start': 28.858,
#      'end': 28.978,
#      'score': 0.418,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'not',
#      'start': 29.018,
#      'end': 29.118,
#      'score': 0.926,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'here',
#      'start': 29.158,
#      'end': 29.279,
#      'score': 0.392,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'to',
#      'start': 29.299,
#      'end': 29.379,
#      'score': 0.582,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'change',
#      'start': 29.439,
#      'end': 29.759,
#      'score': 0.76,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'any',
#      'start': 29.799,
#      'end': 29.939,
#      'score': 0.799,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'of',
#      'start': 29.959,
#      'end': 29.999,
#      'score': 0.722,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'what',
#      'start': 30.039,
#      'end': 30.179,
#      'score': 0.903,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 30.219,
#      'end': 30.32,
#      'score': 0.992,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'have,',
#      'start': 30.36,
#      'end': 30.56,
#      'score': 0.936,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'okay,',
#      'start': 30.68,
#      'end': 30.94,
#      'score': 0.752,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'for',
#      'start': 30.98,
#      'end': 31.16,
#      'score': 0.847,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'starters.',
#      'start': 31.18,
#      'end': 32.101,
#      'score': 0.775,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 32.602,
#    'end': 45.614,
#    'text': "And this is regarding about new guidelines, because you're a business owner, obviously, sir, what we do is we give information that you guys are no longer required to pay any processing fees in terms of the credit or debit cards, it's called zero processing.",
#    'words': [{'word': 'And',
#      'start': 32.602,
#      'end': 32.702,
#      'score': 0.871,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'this',
#      'start': 32.742,
#      'end': 32.922,
#      'score': 0.89,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 32.942,
#      'end': 32.982,
#      'score': 0.696,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'regarding',
#      'start': 33.062,
#      'end': 33.483,
#      'score': 0.864,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'about',
#      'start': 33.563,
#      'end': 33.883,
#      'score': 0.87,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'new',
#      'start': 33.903,
#      'end': 34.223,
#      'score': 0.482,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'guidelines,',
#      'start': 34.243,
#      'end': 34.744,
#      'score': 0.793,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'because',
#      'start': 34.944,
#      'end': 35.184,
#      'score': 0.9,
#      'speaker': 'SPEAKER_01'},
#     {'word': "you're",
#      'start': 35.204,
#      'end': 35.364,
#      'score': 0.777,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'a',
#      'start': 35.384,
#      'end': 35.404,
#      'score': 0.679,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'business',
#      'start': 35.464,
#      'end': 35.785,
#      'score': 0.853,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'owner,',
#      'start': 35.905,
#      'end': 36.225,
#      'score': 0.513,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'obviously,',
#      'start': 36.325,
#      'end': 36.686,
#      'score': 0.946,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir,',
#      'start': 36.746,
#      'end': 36.926,
#      'score': 0.796,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'what',
#      'start': 36.946,
#      'end': 37.106,
#      'score': 0.7,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'we',
#      'start': 37.126,
#      'end': 37.246,
#      'score': 0.734,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do',
#      'start': 37.286,
#      'end': 37.346,
#      'score': 0.286,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 37.386,
#      'end': 37.446,
#      'score': 0.226,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'we',
#      'start': 37.466,
#      'end': 37.606,
#      'score': 0.78,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'give',
#      'start': 37.626,
#      'end': 37.767,
#      'score': 0.957,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'information',
#      'start': 37.827,
#      'end': 38.347,
#      'score': 0.894,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'that',
#      'start': 38.367,
#      'end': 38.507,
#      'score': 0.763,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 38.968,
#      'end': 39.668,
#      'score': 0.766,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'guys',
#      'start': 39.688,
#      'end': 39.849,
#      'score': 0.69,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'are',
#      'start': 39.889,
#      'end': 39.989,
#      'score': 0.834,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'no',
#      'start': 40.029,
#      'end': 40.109,
#      'score': 0.869,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'longer',
#      'start': 40.129,
#      'end': 40.369,
#      'score': 0.828,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'required',
#      'start': 40.429,
#      'end': 40.749,
#      'score': 0.871,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'to',
#      'start': 40.789,
#      'end': 40.849,
#      'score': 0.876,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'pay',
#      'start': 40.91,
#      'end': 41.05,
#      'score': 0.763,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'any',
#      'start': 41.23,
#      'end': 41.39,
#      'score': 0.927,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'processing',
#      'start': 41.55,
#      'end': 42.191,
#      'score': 0.824,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'fees',
#      'start': 42.371,
#      'end': 42.651,
#      'score': 0.76,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'in',
#      'start': 42.691,
#      'end': 42.771,
#      'score': 0.986,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'terms',
#      'start': 42.811,
#      'end': 43.072,
#      'score': 0.836,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'of',
#      'start': 43.132,
#      'end': 43.232,
#      'score': 0.792,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 43.252,
#      'end': 43.312,
#      'score': 0.646,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'credit',
#      'start': 43.392,
#      'end': 43.692,
#      'score': 0.882,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'or',
#      'start': 43.732,
#      'end': 43.812,
#      'score': 0.653,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'debit',
#      'start': 43.872,
#      'end': 44.133,
#      'score': 0.753,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'cards,',
#      'start': 44.153,
#      'end': 44.433,
#      'score': 0.608,
#      'speaker': 'SPEAKER_01'},
#     {'word': "it's",
#      'start': 44.473,
#      'end': 44.553,
#      'score': 0.015,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'called',
#      'start': 44.653,
#      'end': 44.813,
#      'score': 0.642,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'zero',
#      'start': 44.853,
#      'end': 45.113,
#      'score': 0.651,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'processing.',
#      'start': 45.174,
#      'end': 45.614,
#      'score': 0.538,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 46.087,
#    'end': 46.287,
#    'text': ' Okay?',
#    'words': [{'word': 'Okay?',
#      'start': 46.087,
#      'end': 46.287,
#      'score': 0.475,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 46.587,
#    'end': 53.352,
#    'text': "So that's why we share this information so you guys have an idea that you can save money in terms of the credit and debit card.",
#    'words': [{'word': 'So',
#      'start': 46.587,
#      'end': 46.687,
#      'score': 0.994,
#      'speaker': 'SPEAKER_01'},
#     {'word': "that's",
#      'start': 46.727,
#      'end': 46.868,
#      'score': 0.975,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'why',
#      'start': 46.908,
#      'end': 47.008,
#      'score': 0.701,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'we',
#      'start': 47.048,
#      'end': 47.148,
#      'score': 0.734,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'share',
#      'start': 47.168,
#      'end': 47.348,
#      'score': 0.813,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'this',
#      'start': 47.368,
#      'end': 47.488,
#      'score': 0.856,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'information',
#      'start': 47.528,
#      'end': 48.048,
#      'score': 0.893,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'so',
#      'start': 48.208,
#      'end': 48.329,
#      'score': 0.735,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 48.349,
#      'end': 48.429,
#      'score': 0.365,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'guys',
#      'start': 48.449,
#      'end': 48.649,
#      'score': 0.543,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'have',
#      'start': 48.669,
#      'end': 49.149,
#      'score': 0.538,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'an',
#      'start': 49.309,
#      'end': 49.389,
#      'score': 0.655,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'idea',
#      'start': 49.449,
#      'end': 49.81,
#      'score': 0.924,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'that',
#      'start': 50.21,
#      'end': 50.33,
#      'score': 0.885,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 50.35,
#      'end': 50.45,
#      'score': 0.987,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'can',
#      'start': 50.49,
#      'end': 50.63,
#      'score': 0.982,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'save',
#      'start': 50.71,
#      'end': 50.95,
#      'score': 0.798,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'money',
#      'start': 51.03,
#      'end': 51.25,
#      'score': 0.829,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'in',
#      'start': 51.691,
#      'end': 51.851,
#      'score': 0.558,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'terms',
#      'start': 51.891,
#      'end': 52.091,
#      'score': 0.577,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'of',
#      'start': 52.131,
#      'end': 52.291,
#      'score': 0.546,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 52.311,
#      'end': 52.431,
#      'score': 0.349,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'credit',
#      'start': 52.471,
#      'end': 52.651,
#      'score': 0.371,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'and',
#      'start': 52.691,
#      'end': 52.832,
#      'score': 0.294,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'debit',
#      'start': 52.892,
#      'end': 53.132,
#      'score': 0.669,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'card.',
#      'start': 53.152,
#      'end': 53.352,
#      'score': 0.731,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 53.652,
#    'end': 54.793,
#    'text': "So it's called zero processing.",
#    'words': [{'word': 'So',
#      'start': 53.652,
#      'end': 53.752,
#      'score': 0.742,
#      'speaker': 'SPEAKER_01'},
#     {'word': "it's",
#      'start': 53.772,
#      'end': 53.852,
#      'score': 0.03,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'called',
#      'start': 53.872,
#      'end': 54.012,
#      'score': 0.328,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'zero',
#      'start': 54.032,
#      'end': 54.313,
#      'score': 0.786,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'processing.',
#      'start': 54.333,
#      'end': 54.793,
#      'score': 0.693,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 54.833,
#    'end': 63.018,
#    'text': 'Now, my colleague, sir, will definitely reach you back tomorrow and he will give you how it works for only less than two minutes and the benefits of zero processing.',
#    'words': [{'word': 'Now,',
#      'start': 54.833,
#      'end': 54.973,
#      'score': 0.973,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'my',
#      'start': 55.053,
#      'end': 55.233,
#      'score': 0.98,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'colleague,',
#      'start': 55.313,
#      'end': 55.653,
#      'score': 0.532,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir,',
#      'start': 55.673,
#      'end': 55.834,
#      'score': 0.536,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'will',
#      'start': 55.854,
#      'end': 56.034,
#      'score': 0.78,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'definitely',
#      'start': 56.114,
#      'end': 56.534,
#      'score': 0.915,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'reach',
#      'start': 56.594,
#      'end': 56.754,
#      'score': 0.907,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 56.794,
#      'end': 56.894,
#      'score': 0.98,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'back',
#      'start': 56.934,
#      'end': 57.074,
#      'score': 0.915,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'tomorrow',
#      'start': 57.134,
#      'end': 57.415,
#      'score': 0.54,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'and',
#      'start': 57.435,
#      'end': 57.515,
#      'score': 0.3,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'he',
#      'start': 57.555,
#      'end': 57.635,
#      'score': 0.485,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'will',
#      'start': 57.655,
#      'end': 57.835,
#      'score': 0.888,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'give',
#      'start': 58.255,
#      'end': 58.435,
#      'score': 0.784,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 58.475,
#      'end': 58.615,
#      'score': 0.805,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'how',
#      'start': 59.096,
#      'end': 59.256,
#      'score': 0.895,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'it',
#      'start': 59.316,
#      'end': 59.376,
#      'score': 0.837,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'works',
#      'start': 59.416,
#      'end': 59.716,
#      'score': 0.838,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'for',
#      'start': 59.836,
#      'end': 59.976,
#      'score': 0.758,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'only',
#      'start': 60.016,
#      'end': 60.216,
#      'score': 0.891,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'less',
#      'start': 60.297,
#      'end': 60.477,
#      'score': 0.6,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'than',
#      'start': 60.497,
#      'end': 60.597,
#      'score': 0.382,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'two',
#      'start': 60.637,
#      'end': 60.777,
#      'score': 0.825,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'minutes',
#      'start': 60.797,
#      'end': 61.057,
#      'score': 0.782,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'and',
#      'start': 61.197,
#      'end': 61.297,
#      'score': 0.674,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 61.337,
#      'end': 61.597,
#      'score': 0.752,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'benefits',
#      'start': 61.637,
#      'end': 61.998,
#      'score': 0.882,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'of',
#      'start': 62.038,
#      'end': 62.118,
#      'score': 0.848,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'zero',
#      'start': 62.318,
#      'end': 62.538,
#      'score': 0.434,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'processing.',
#      'start': 62.558,
#      'end': 63.018,
#      'score': 0.752,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 63.038,
#    'end': 67.181,
#    'text': 'So my question here, Mr. Patel, is what would be the best time, sir, to reach you back tomorrow?',
#    'words': [{'word': 'So',
#      'start': 63.038,
#      'end': 63.178,
#      'score': 0.921,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'my',
#      'start': 63.218,
#      'end': 63.359,
#      'score': 0.883,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'question',
#      'start': 63.419,
#      'end': 63.739,
#      'score': 0.887,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'here,',
#      'start': 63.759,
#      'end': 63.879,
#      'score': 0.588,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'Mr.',
#      'start': 63.919,
#      'end': 64.159,
#      'score': 0.732,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'Patel,',
#      'start': 64.219,
#      'end': 64.499,
#      'score': 0.811,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 64.519,
#      'end': 64.619,
#      'score': 0.678,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'what',
#      'start': 65.04,
#      'end': 65.16,
#      'score': 0.901,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'would',
#      'start': 65.18,
#      'end': 65.32,
#      'score': 0.851,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'be',
#      'start': 65.34,
#      'end': 65.42,
#      'score': 0.502,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 65.44,
#      'end': 65.52,
#      'score': 0.819,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'best',
#      'start': 65.56,
#      'end': 65.72,
#      'score': 0.907,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'time,',
#      'start': 65.76,
#      'end': 65.94,
#      'score': 0.717,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir,',
#      'start': 65.98,
#      'end': 66.14,
#      'score': 0.767,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'to',
#      'start': 66.241,
#      'end': 66.341,
#      'score': 0.99,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'reach',
#      'start': 66.381,
#      'end': 66.521,
#      'score': 0.533,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 66.561,
#      'end': 66.661,
#      'score': 0.861,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'back',
#      'start': 66.681,
#      'end': 66.821,
#      'score': 0.784,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'tomorrow?',
#      'start': 66.861,
#      'end': 67.181,
#      'score': 0.847,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 67.201,
#    'end': 69.202,
#    'text': 'Would it be in the morning, sir, or in the afternoon?',
#    'words': [{'word': 'Would',
#      'start': 67.201,
#      'end': 67.361,
#      'score': 0.793,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'it',
#      'start': 67.401,
#      'end': 67.441,
#      'score': 0.946,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'be',
#      'start': 67.481,
#      'end': 67.541,
#      'score': 0.705,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'in',
#      'start': 67.561,
#      'end': 67.621,
#      'score': 0.718,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 67.661,
#      'end': 67.742,
#      'score': 0.905,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'morning,',
#      'start': 67.782,
#      'end': 68.062,
#      'score': 0.884,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir,',
#      'start': 68.082,
#      'end': 68.322,
#      'score': 0.891,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'or',
#      'start': 68.422,
#      'end': 68.482,
#      'score': 0.987,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'in',
#      'start': 68.602,
#      'end': 68.662,
#      'score': 0.991,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 68.682,
#      'end': 68.782,
#      'score': 0.813,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'afternoon?',
#      'start': 68.842,
#      'end': 69.202,
#      'score': 0.952,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 69.283,
#    'end': 69.943,
#    'text': "You're the boss, sir.",
#    'words': [{'word': "You're",
#      'start': 69.283,
#      'end': 69.423,
#      'score': 0.642,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 69.463,
#      'end': 69.563,
#      'score': 0.434,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'boss,',
#      'start': 69.583,
#      'end': 69.743,
#      'score': 0.529,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir.',
#      'start': 69.763,
#      'end': 69.943,
#      'score': 0.669,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 70.003,
#    'end': 70.543,
#    'text': 'Give me the time.',
#    'words': [{'word': 'Give',
#      'start': 70.003,
#      'end': 70.143,
#      'score': 0.956,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'me',
#      'start': 70.163,
#      'end': 70.223,
#      'score': 0.259,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 70.243,
#      'end': 70.323,
#      'score': 0.636,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'time.',
#      'start': 70.363,
#      'end': 70.543,
#      'score': 0.963,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 72.685,
#    'end': 72.965,
#    'text': 'Evening.',
#    'words': [{'word': 'Evening.',
#      'start': 72.685,
#      'end': 72.965,
#      'score': 0.769,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 73.946,
#    'end': 74.186,
#    'text': 'Evening?',
#    'words': [{'word': 'Evening?',
#      'start': 73.946,
#      'end': 74.186,
#      'score': 0.979,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 74.246,
#    'end': 75.086,
#    'text': 'Like 6 p.m., sir?',
#    'words': [{'word': 'Like',
#      'start': 74.246,
#      'end': 74.366,
#      'score': 0.863,
#      'speaker': 'SPEAKER_00'},
#     {'word': '6'},
#     {'word': 'p.m.,',
#      'start': 74.666,
#      'end': 74.926,
#      'score': 0.684,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir?',
#      'start': 74.946,
#      'end': 75.086,
#      'score': 0.478,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 75.126,
#    'end': 75.827,
#    'text': 'Would that be perfect?',
#    'words': [{'word': 'Would',
#      'start': 75.126,
#      'end': 75.247,
#      'score': 0.711,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'that',
#      'start': 75.267,
#      'end': 75.367,
#      'score': 0.416,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'be',
#      'start': 75.387,
#      'end': 75.487,
#      'score': 0.793,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'perfect?',
#      'start': 75.527,
#      'end': 75.827,
#      'score': 0.963,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 76.914,
#    'end': 77.154,
#    'text': ' Yeah.',
#    'words': [{'word': 'Yeah.',
#      'start': 76.914,
#      'end': 77.154,
#      'score': 0.666,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 77.174,
#    'end': 78.375,
#    'text': '6 p.m.',
#    'words': [{'word': '6'},
#     {'word': 'p.m.',
#      'start': 78.175,
#      'end': 78.375,
#      'score': 0.326,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 78.455,
#    'end': 79.975,
#    'text': 'Sir, Patel at this number 812-361-6141.',
#    'words': [{'word': 'Sir,',
#      'start': 78.455,
#      'end': 78.555,
#      'score': 0.555,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'Patel',
#      'start': 78.595,
#      'end': 78.875,
#      'score': 0.866,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'at',
#      'start': 78.895,
#      'end': 78.995,
#      'score': 0.612,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'this',
#      'start': 79.015,
#      'end': 79.155,
#      'score': 0.702,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'number',
#      'start': 79.195,
#      'end': 79.475,
#      'score': 0.903,
#      'speaker': 'SPEAKER_01'},
#     {'word': '812-361-6141.',
#      'start': 79.495,
#      'end': 79.975,
#      'score': 0.25,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 81.976,
#    'end': 83.717,
#    'text': "And what's your business name, sir?",
#    'words': [{'word': 'And',
#      'start': 81.976,
#      'end': 82.637,
#      'score': 0.7,
#      'speaker': 'SPEAKER_01'},
#     {'word': "what's",
#      'start': 82.677,
#      'end': 82.837,
#      'score': 0.752,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'your',
#      'start': 82.877,
#      'end': 83.017,
#      'score': 0.867,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'business',
#      'start': 83.057,
#      'end': 83.337,
#      'score': 0.916,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'name,',
#      'start': 83.357,
#      'end': 83.537,
#      'score': 0.914,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir?',
#      'start': 83.577,
#      'end': 83.717,
#      'score': 0.847,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 83.737,
#    'end': 87.959,
#    'text': "Sir, actually, I don't have a business.",
#    'words': [{'word': 'Sir,',
#      'start': 83.737,
#      'end': 86.298,
#      'score': 0.747,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'actually,',
#      'start': 86.798,
#      'end': 87.119,
#      'score': 0.67,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 87.139,
#      'end': 87.179,
#      'score': 0.402,
#      'speaker': 'SPEAKER_00'},
#     {'word': "don't",
#      'start': 87.199,
#      'end': 87.319,
#      'score': 0.382,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'have',
#      'start': 87.339,
#      'end': 87.459,
#      'score': 0.679,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 87.479,
#      'end': 87.499,
#      'score': 0.007,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'business.',
#      'start': 87.519,
#      'end': 87.959,
#      'score': 0.804,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 88.899,
#    'end': 90.3,
#    'text': "Oh, you don't have any business?",
#    'words': [{'word': 'Oh,',
#      'start': 88.899,
#      'end': 89.079,
#      'score': 0.691,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 89.42,
#      'end': 89.5,
#      'score': 0.918,
#      'speaker': 'SPEAKER_01'},
#     {'word': "don't",
#      'start': 89.54,
#      'end': 89.66,
#      'score': 0.899,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'have',
#      'start': 89.68,
#      'end': 89.8,
#      'score': 0.825,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'any',
#      'start': 89.84,
#      'end': 89.92,
#      'score': 0.998,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'business?',
#      'start': 89.96,
#      'end': 90.3,
#      'score': 0.862,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 90.32,
#    'end': 91.06,
#    'text': 'Are you sure?',
#    'words': [{'word': 'Are',
#      'start': 90.32,
#      'end': 90.38,
#      'score': 0.066,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 90.76,
#      'end': 90.84,
#      'score': 0.687,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sure?',
#      'start': 90.88,
#      'end': 91.06,
#      'score': 0.686,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 91.08,
#    'end': 93.101,
#    'text': "Because this is a business number that we're calling.",
#    'words': [{'word': 'Because',
#      'start': 91.08,
#      'end': 91.38,
#      'score': 0.718,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'this',
#      'start': 91.4,
#      'end': 91.54,
#      'score': 0.818,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 91.58,
#      'end': 91.64,
#      'score': 0.666,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'a',
#      'start': 91.68,
#      'end': 91.741,
#      'score': 0.416,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'business',
#      'start': 91.761,
#      'end': 92.041,
#      'score': 0.588,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'number',
#      'start': 92.061,
#      'end': 92.241,
#      'score': 0.49,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'that',
#      'start': 92.261,
#      'end': 92.501,
#      'score': 0.326,
#      'speaker': 'SPEAKER_01'},
#     {'word': "we're",
#      'start': 92.541,
#      'end': 92.701,
#      'score': 0.313,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'calling.',
#      'start': 92.721,
#      'end': 93.101,
#      'score': 0.877,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 93.681,
#    'end': 99.644,
#    'text': "And so this is a private number and you're only working or what do you do, sir, for a living?",
#    'words': [{'word': 'And',
#      'start': 93.681,
#      'end': 93.801,
#      'score': 0.9,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'so',
#      'start': 94.142,
#      'end': 94.622,
#      'score': 0.861,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'this',
#      'start': 94.762,
#      'end': 94.902,
#      'score': 0.968,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 94.962,
#      'end': 95.042,
#      'score': 0.732,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'a',
#      'start': 95.082,
#      'end': 95.122,
#      'score': 0.506,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'private',
#      'start': 95.182,
#      'end': 95.502,
#      'score': 0.879,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'number',
#      'start': 95.542,
#      'end': 95.802,
#      'score': 0.917,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'and',
#      'start': 96.002,
#      'end': 96.122,
#      'score': 0.812,
#      'speaker': 'SPEAKER_01'},
#     {'word': "you're",
#      'start': 96.763,
#      'end': 97.023,
#      'score': 0.763,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'only',
#      'start': 97.143,
#      'end': 97.363,
#      'score': 0.974,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'working',
#      'start': 97.403,
#      'end': 97.743,
#      'score': 0.896,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'or',
#      'start': 97.883,
#      'end': 98.063,
#      'score': 0.655,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'what',
#      'start': 98.483,
#      'end': 98.624,
#      'score': 0.901,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do',
#      'start': 98.644,
#      'end': 98.724,
#      'score': 0.887,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 98.744,
#      'end': 98.824,
#      'score': 0.977,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do,',
#      'start': 98.864,
#      'end': 98.944,
#      'score': 0.985,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir,',
#      'start': 98.984,
#      'end': 99.144,
#      'score': 0.76,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'for',
#      'start': 99.164,
#      'end': 99.304,
#      'score': 0.882,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'a',
#      'start': 99.324,
#      'end': 99.344,
#      'score': 0.839,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'living?',
#      'start': 99.384,
#      'end': 99.644,
#      'score': 0.91,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 101.365,
#    'end': 101.805,
#    'text': 'Yeah.',
#    'words': [{'word': 'Yeah.',
#      'start': 101.365,
#      'end': 101.805,
#      'score': 0.709,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 102.225,
#    'end': 104.426,
#    'text': 'So, like, I did not get it.',
#    'words': [{'word': 'So,',
#      'start': 102.225,
#      'end': 102.425,
#      'score': 0.958,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like,',
#      'start': 102.785,
#      'end': 102.985,
#      'score': 0.792,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 103.666,
#      'end': 103.726,
#      'score': 0.967,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'did',
#      'start': 103.746,
#      'end': 103.886,
#      'score': 0.939,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'not',
#      'start': 103.926,
#      'end': 104.046,
#      'score': 0.984,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'get',
#      'start': 104.086,
#      'end': 104.306,
#      'score': 0.656,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'it.',
#      'start': 104.346,
#      'end': 104.426,
#      'score': 0.814,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 104.466,
#    'end': 105.747,
#    'text': 'Like, what company is it?',
#    'words': [{'word': 'Like,',
#      'start': 104.466,
#      'end': 104.646,
#      'score': 0.782,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'what',
#      'start': 104.666,
#      'end': 105.066,
#      'score': 0.63,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'company',
#      'start': 105.126,
#      'end': 105.487,
#      'score': 0.929,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is',
#      'start': 105.527,
#      'end': 105.607,
#      'score': 0.77,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'it?',
#      'start': 105.687,
#      'end': 105.747,
#      'score': 0.848,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 105.787,
#    'end': 106.327,
#    'text': 'Like, or what?',
#    'words': [{'word': 'Like,',
#      'start': 105.787,
#      'end': 105.947,
#      'score': 0.861,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'or',
#      'start': 106.007,
#      'end': 106.107,
#      'score': 0.598,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'what?',
#      'start': 106.167,
#      'end': 106.327,
#      'score': 0.414,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 107.388,
#    'end': 110.39,
#    'text': " I've anticipated what we do, sir.",
#    'words': [{'word': "I've",
#      'start': 107.388,
#      'end': 108.989,
#      'score': 0.689,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'anticipated',
#      'start': 109.029,
#      'end': 109.589,
#      'score': 0.929,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'what',
#      'start': 109.609,
#      'end': 109.689,
#      'score': 0.079,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'we',
#      'start': 109.709,
#      'end': 109.99,
#      'score': 0.589,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'do,',
#      'start': 110.01,
#      'end': 110.15,
#      'score': 0.76,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir.',
#      'start': 110.17,
#      'end': 110.39,
#      'score': 0.619,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 111.191,
#    'end': 111.591,
#    'text': 'Yes, sir.',
#    'words': [{'word': 'Yes,',
#      'start': 111.191,
#      'end': 111.371,
#      'score': 0.985,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir.',
#      'start': 111.411,
#      'end': 111.591,
#      'score': 0.769,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 111.751,
#    'end': 116.955,
#    'text': 'But like I said, if you do have a business, which definitely, we all know you have, sir.',
#    'words': [{'word': 'But',
#      'start': 111.751,
#      'end': 112.272,
#      'score': 0.734,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'like',
#      'start': 112.592,
#      'end': 112.772,
#      'score': 0.838,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'I',
#      'start': 112.812,
#      'end': 112.872,
#      'score': 0.694,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'said,',
#      'start': 112.912,
#      'end': 113.212,
#      'score': 0.651,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'if',
#      'start': 113.653,
#      'end': 113.733,
#      'score': 0.994,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 113.773,
#      'end': 113.893,
#      'score': 0.892,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do',
#      'start': 113.913,
#      'end': 114.033,
#      'score': 0.978,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'have',
#      'start': 114.053,
#      'end': 114.193,
#      'score': 0.85,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'a',
#      'start': 114.233,
#      'end': 114.253,
#      'score': 0.984,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'business,',
#      'start': 114.313,
#      'end': 114.633,
#      'score': 0.923,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'which',
#      'start': 114.653,
#      'end': 114.814,
#      'score': 0.898,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'definitely,',
#      'start': 114.834,
#      'end': 115.554,
#      'score': 0.374,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'we',
#      'start': 115.614,
#      'end': 116.075,
#      'score': 0.736,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'all',
#      'start': 116.135,
#      'end': 116.235,
#      'score': 0.806,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'know',
#      'start': 116.275,
#      'end': 116.435,
#      'score': 0.93,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 116.455,
#      'end': 116.595,
#      'score': 0.828,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'have,',
#      'start': 116.635,
#      'end': 116.795,
#      'score': 0.873,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir.',
#      'start': 116.835,
#      'end': 116.955,
#      'score': 0.677,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 116.995,
#    'end': 118.617,
#    'text': "That's why I'm thinking right now.",
#    'words': [{'word': "That's",
#      'start': 116.995,
#      'end': 117.196,
#      'score': 0.27,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'why',
#      'start': 117.236,
#      'end': 117.596,
#      'score': 0.615,
#      'speaker': 'SPEAKER_01'},
#     {'word': "I'm",
#      'start': 117.776,
#      'end': 117.896,
#      'score': 0.698,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'thinking',
#      'start': 117.936,
#      'end': 118.256,
#      'score': 0.753,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'right',
#      'start': 118.296,
#      'end': 118.437,
#      'score': 0.496,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'now.',
#      'start': 118.477,
#      'end': 118.617,
#      'score': 0.921,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 119.337,
#    'end': 122.68,
#    'text': 'What we do, sir, is we share this information to business owners just like yourself.',
#    'words': [{'word': 'What',
#      'start': 119.337,
#      'end': 119.477,
#      'score': 0.79,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'we',
#      'start': 119.497,
#      'end': 119.637,
#      'score': 0.618,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do,',
#      'start': 119.678,
#      'end': 119.758,
#      'score': 0.74,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sir,',
#      'start': 119.778,
#      'end': 119.878,
#      'score': 0.732,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 119.918,
#      'end': 119.978,
#      'score': 0.441,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'we',
#      'start': 120.018,
#      'end': 120.138,
#      'score': 0.826,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'share',
#      'start': 120.178,
#      'end': 120.358,
#      'score': 0.844,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'this',
#      'start': 120.378,
#      'end': 120.518,
#      'score': 0.71,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'information',
#      'start': 120.558,
#      'end': 121.119,
#      'score': 0.938,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'to',
#      'start': 121.139,
#      'end': 121.259,
#      'score': 0.845,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'business',
#      'start': 121.279,
#      'end': 121.579,
#      'score': 0.868,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'owners',
#      'start': 121.639,
#      'end': 121.879,
#      'score': 0.759,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'just',
#      'start': 121.919,
#      'end': 122.099,
#      'score': 0.757,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'like',
#      'start': 122.119,
#      'end': 122.26,
#      'score': 0.972,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'yourself.',
#      'start': 122.3,
#      'end': 122.68,
#      'score': 0.848,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 123.24,
#    'end': 126.863,
#    'text': "So definitely, if you're a business owner, definitely you have a credit card machine, right?",
#    'words': [{'word': 'So',
#      'start': 123.24,
#      'end': 123.481,
#      'score': 0.715,
#      'speaker': 'SPEAKER_01'},
# ...
#   {'word': 'and',
#    'start': 284.87,
#    'end': 284.93,
#    'score': 0.216,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'sell',
#    'start': 285.05,
#    'end': 285.39,
#    'score': 0.902,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'in',
#    'start': 285.87,
#    'end': 285.95,
#    'score': 0.937,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'terms',
#    'start': 285.97,
#    'end': 286.39,
#    'score': 0.676,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'of.',
#    'start': 287.111,
#    'end': 287.411,
#    'score': 0.353,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'But',
#    'start': 288.511,
#    'end': 288.651,
#    'score': 0.907,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'the',
#    'start': 288.691,
#    'end': 288.791,
#    'score': 0.868,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'thing',
#    'start': 288.811,
#    'end': 289.031,
#    'score': 0.921,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'is',
#    'start': 289.131,
#    'end': 289.231,
#    'score': 0.824,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'I',
#    'start': 289.291,
#    'end': 289.351,
#    'score': 0.675,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'was',
#    'start': 289.371,
#    'end': 289.511,
#    'score': 0.791,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'doing',
#    'start': 289.531,
#    'end': 289.771,
#    'score': 0.865,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'it',
#    'start': 289.811,
#    'end': 289.891,
#    'score': 0.914,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'at',
#    'start': 289.971,
#    'end': 290.031,
#    'score': 0.972,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'part',
#    'start': 290.131,
#    'end': 290.372,
#    'score': 0.891,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'time',
#    'start': 290.392,
#    'end': 290.672,
#    'score': 0.742,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'and',
#    'start': 290.912,
#    'end': 291.072,
#    'score': 0.806,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'I',
#    'start': 291.512,
#    'end': 291.572,
#    'score': 0.697,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'was',
#    'start': 291.612,
#    'end': 291.732,
#    'score': 0.993,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'not',
#    'start': 291.792,
#    'end': 291.952,
#    'score': 0.825,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'really',
#    'start': 291.972,
#    'end': 292.252,
#    'score': 0.669,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'focused',
#    'start': 292.292,
#    'end': 292.712,
#    'score': 0.583,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'on',
#    'start': 292.772,
#    'end': 292.852,
#    'score': 0.854,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'it.',
#    'start': 292.912,
#    'end': 293.012,
#    'score': 0.845,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'And',
#    'start': 293.413,
#    'end': 293.493,
#    'score': 0.831,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'I',
#    'start': 293.533,
#    'end': 293.613,
#    'score': 0.805,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'tried',
#    'start': 293.673,
#    'end': 293.993,
#    'score': 0.803,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'to',
#    'start': 294.053,
#    'end': 294.233,
#    'score': 0.898,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'hire',
#    'start': 294.313,
#    'end': 294.633,
#    'score': 0.759,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'some',
#    'start': 294.673,
#    'end': 294.853,
#    'score': 0.372,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'other',
#    'start': 294.973,
#    'end': 295.173,
#    'score': 0.862,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'party,',
#    'start': 295.213,
#    'end': 295.573,
#    'score': 0.893,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'but',
#    'start': 295.613,
#    'end': 295.773,
#    'score': 0.938,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'they',
#    'start': 295.973,
#    'end': 296.513,
#    'score': 0.611,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'have',
#    'start': 296.614,
#    'end': 297.314,
#    'score': 0.722,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'not',
#    'start': 297.474,
#    'end': 297.674,
#    'score': 0.844,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'good.',
#    'start': 297.814,
#    'end': 298.034,
#    'score': 0.77,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'So',
#    'start': 298.683,
#    'end': 298.723,
#    'score': 0.003,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'I',
#    'start': 298.743,
#    'end': 298.823,
#    'score': 0.582,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'was',
#    'start': 298.843,
#    'end': 298.983,
#    'score': 0.601,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'just',
#    'start': 299.003,
#    'end': 299.163,
#    'score': 0.42,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'losing',
#    'start': 299.243,
#    'end': 299.584,
#    'score': 0.854,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'the',
#    'start': 299.644,
#    'end': 299.744,
#    'score': 0.929,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'money.',
#    'start': 299.784,
#    'end': 300.064,
#    'score': 0.794,
#    'speaker': 'SPEAKER_00'},
#   {'word': "That's",
#    'start': 300.644,
#    'end': 300.844,
#    'score': 0.556,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'why',
#    'start': 300.924,
#    'end': 301.405,
#    'score': 0.586,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'right',
#    'start': 301.545,
#    'end': 301.745,
#    'score': 0.437,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'now',
#    'start': 301.765,
#    'end': 301.925,
#    'score': 0.725,
#    'speaker': 'SPEAKER_00'},
#   {'word': "it's",
#    'start': 301.985,
#    'end': 302.225,
#    'score': 0.459,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'barely',
#    'start': 302.425,
#    'end': 302.806,
#    'score': 0.754,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'selling',
#    'start': 302.846,
#    'end': 303.166,
#    'score': 0.904,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'one',
#    'start': 303.326,
#    'end': 303.466,
#    'score': 0.575,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'or',
#    'start': 303.526,
#    'end': 303.686,
#    'score': 0.532,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'zero',
#    'start': 303.866,
#    'end': 304.267,
#    'score': 0.73,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'a',
#    'start': 304.367,
#    'end': 304.427,
#    'score': 0.555,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'day.',
#    'start': 304.467,
#    'end': 304.687,
#    'score': 0.828,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'So',
#    'start': 305.567,
#    'end': 305.788,
#    'score': 0.71,
#    'speaker': 'SPEAKER_00'},
#   {'word': "that's",
#    'start': 305.828,
#    'end': 306.008,
#    'score': 0.426,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'why.',
#    'start': 306.068,
#    'end': 306.288,
#    'score': 0.479,
#    'speaker': 'SPEAKER_00'},
#   {'word': "There's",
#    'start': 306.328,
#    'end': 306.508,
#    'score': 0.345,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'a',
#    'start': 306.528,
#    'end': 306.568,
#    'score': 0.464,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'lot',
#    'start': 306.608,
#    'end': 306.728,
#    'score': 0.985,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'of',
#    'start': 306.748,
#    'end': 306.808,
#    'score': 0.691,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'competition,',
#    'start': 306.848,
#    'end': 307.409,
#    'score': 0.816,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'right?',
#    'start': 307.469,
#    'end': 307.669,
#    'score': 0.456,
#    'speaker': 'SPEAKER_00'},
#   {'word': "There's",
#    'start': 307.989,
#    'end': 308.209,
#    'score': 0.714,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'a',
#    'start': 308.229,
#    'end': 308.249,
#    'score': 0.98,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'lot',
#    'start': 308.289,
#    'end': 308.449,
#    'score': 0.901,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'of',
#    'start': 308.469,
#    'end': 308.529,
#    'score': 0.734,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'competition',
#    'start': 308.569,
#    'end': 309.89,
#    'score': 0.728,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'and',
#    'start': 310.23,
#    'end': 310.35,
#    'score': 0.871,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'some,',
#    'start': 310.431,
#    'end': 310.871,
#    'score': 0.872,
#    'speaker': 'SPEAKER_01'},
#   {'word': "let's",
#    'start': 310.931,
#    'end': 311.111,
#    'score': 0.612,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'say',
#    'start': 311.131,
#    'end': 311.271,
#    'score': 0.675,
#    'speaker': 'SPEAKER_01'},
#   {'word': "you're",
#    'start': 311.291,
#    'end': 311.471,
#    'score': 0.609,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'selling',
#    'start': 311.511,
#    'end': 311.851,
#    'score': 0.711,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'stuff.',
#    'start': 311.871,
#    'end': 312.112,
#    'score': 0.662,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'This',
#    'start': 312.172,
#    'end': 312.312,
#    'score': 0.908,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'is',
#    'start': 312.352,
#    'end': 312.412,
#    'score': 0.752,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'only',
#    'start': 312.452,
#    'end': 312.592,
#    'score': 0.831,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'an',
#    'start': 312.612,
#    'end': 312.672,
#    'score': 0.678,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'example.',
#    'start': 312.712,
#    'end': 313.132,
#    'score': 0.929,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'And',
#    'start': 313.512,
#    'end': 313.593,
#    'score': 0.911,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'then',
#    'start': 313.613,
#    'end': 313.753,
#    'score': 0.745,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you',
#    'start': 313.773,
#    'end': 313.853,
#    'score': 0.99,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'will',
#    'start': 313.873,
#    'end': 314.013,
#    'score': 0.899,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'see',
#    'start': 314.053,
#    'end': 314.153,
#    'score': 0.851,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'online,',
#    'start': 314.213,
#    'end': 314.673,
#    'score': 0.397,
#    'speaker': 'SPEAKER_01'},
#   {'word': "let's",
#    'start': 315.114,
#    'end': 315.294,
#    'score': 0.682,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'say',
#    'start': 315.314,
#    'end': 315.614,
#    'score': 0.641,
#    'speaker': 'SPEAKER_01'},
#   {'word': "you're",
#    'start': 315.634,
#    'end': 315.754,
#    'score': 0.31,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'selling',
#    'start': 315.774,
#    'end': 316.014,
#    'score': 0.925,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'it',
#    'start': 316.054,
#    'end': 316.114,
#    'score': 0.969,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'for',
#    'start': 316.154,
#    'end': 316.274,
#    'score': 0.996,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'only',
#    'start': 316.334,
#    'end': 316.534,
#    'score': 0.78,
#    'speaker': 'SPEAKER_01'},
#   {'word': '$5.'},
#   {'word': 'This',
#    'start': 316.574,
#    'end': 317.195,
#    'score': 0.422,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'is',
#    'start': 317.335,
#    'end': 317.435,
#    'score': 0.7,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'just',
#    'start': 317.475,
#    'end': 317.655,
#    'score': 0.728,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'an',
#    'start': 317.675,
#    'end': 317.755,
#    'score': 0.784,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'example.',
#    'start': 317.795,
#    'end': 318.155,
#    'score': 0.845,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'And',
#    'start': 318.195,
#    'end': 318.256,
#    'score': 0.981,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'then',
#    'start': 318.296,
#    'end': 318.416,
#    'score': 0.836,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'when',
#    'start': 318.536,
#    'end': 318.656,
#    'score': 0.276,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you',
#    'start': 318.676,
#    'end': 318.736,
#    'score': 0.344,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'see',
#    'start': 318.776,
#    'end': 318.896,
#    'score': 0.904,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'on',
#    'start': 318.976,
#    'end': 319.096,
#    'score': 0.486,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'Amazon,',
#    'start': 319.196,
#    'end': 320.237,
#    'score': 0.822,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'your',
#    'start': 320.257,
#    'end': 320.397,
#    'score': 0.831,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'competitors',
#    'start': 320.417,
#    'end': 320.897,
#    'score': 0.751,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'are',
#    'start': 320.957,
#    'end': 321.037,
#    'score': 0.613,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'selling',
#    'start': 321.057,
#    'end': 321.337,
#    'score': 0.938,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'it',
#    'start': 321.398,
#    'end': 321.458,
#    'score': 0.78,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'for',
#    'start': 321.498,
#    'end': 322.118,
#    'score': 0.661,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'only',
#    'start': 322.218,
#    'end': 322.458,
#    'score': 0.505,
#    'speaker': 'SPEAKER_01'},
#   {'word': '$3.'},
#   {'word': 'Some',
#    'start': 322.999,
#    'end': 323.339,
#    'score': 0.849,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'people',
#    'start': 323.359,
#    'end': 323.579,
#    'score': 0.927,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'are',
#    'start': 323.639,
#    'end': 323.919,
#    'score': 0.629,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'like',
#    'start': 323.959,
#    'end': 324.179,
#    'score': 0.358,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'that.',
#    'start': 324.379,
#    'end': 324.56,
#    'score': 0.421,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'You',
#    'start': 324.6,
#    'end': 324.7,
#    'score': 0.968,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'were',
#    'start': 324.72,
#    'end': 324.84,
#    'score': 0.925,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'like,',
#    'start': 324.86,
#    'end': 325.0,
#    'score': 0.769,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'oh',
#    'start': 325.06,
#    'end': 325.16,
#    'score': 0.408,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'my',
#    'start': 325.18,
#    'end': 325.26,
#    'score': 0.778,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'gosh,',
#    'start': 325.3,
#    'end': 325.54,
#    'score': 0.609,
#    'speaker': 'SPEAKER_00'},
#   {'word': "I'm",
#    'start': 325.68,
#    'end': 325.8,
#    'score': 0.436,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'a',
#    'start': 326.241,
#    'end': 326.341,
#    'score': 0.592,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'bit',
#    'start': 326.361,
#    'end': 326.461,
#    'score': 0.567,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'higher',
#    'start': 326.601,
#    'end': 326.881,
#    'score': 0.646,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'for',
#    'start': 326.901,
#    'end': 327.021,
#    'score': 0.772,
#    'speaker': 'SPEAKER_01'},
#   {'word': '$2'},
#   {'word': 'here.',
#    'start': 327.081,
#    'end': 327.181,
#    'score': 0.125,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'Sometimes',
#    'start': 328.683,
#    'end': 329.023,
#    'score': 0.921,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'they',
#    'start': 329.063,
#    'end': 329.203,
#    'score': 0.515,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'change',
#    'start': 329.223,
#    'end': 329.463,
#    'score': 0.412,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'that.',
#    'start': 329.503,
#    'end': 329.684,
#    'score': 0.68,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'So',
#    'start': 329.744,
#    'end': 330.084,
#    'score': 0.71,
#    'speaker': 'SPEAKER_01'},
#   {'word': "it's",
#    'start': 330.224,
#    'end': 330.564,
#    'score': 0.759,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'supply',
#    'start': 330.584,
#    'end': 330.884,
#    'score': 0.761,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'and',
#    'start': 330.924,
#    'end': 331.004,
#    'score': 0.474,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'demand.',
#    'start': 331.044,
#    'end': 331.384,
#    'score': 0.879,
#    'speaker': 'SPEAKER_01'},
#   {'word': "It's",
#    'start': 331.464,
#    'end': 331.564,
#    'score': 0.608,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'a',
#    'start': 331.624,
#    'end': 331.664,
#    'score': 0.358,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'numbers',
#    'start': 331.724,
#    'end': 332.025,
#    'score': 0.862,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'game.',
#    'start': 332.065,
#    'end': 332.345,
#    'score': 0.768,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'And',
#    'start': 332.945,
#    'end': 333.045,
#    'score': 0.892,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'sometimes',
#    'start': 333.305,
#    'end': 333.685,
#    'score': 0.839,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'sellers',
#    'start': 333.725,
#    'end': 334.006,
#    'score': 0.519,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'are',
#    'start': 334.086,
#    'end': 334.186,
#    'score': 0.691,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'really',
#    'start': 334.206,
#    'end': 334.626,
#    'score': 0.656,
#    'speaker': 'SPEAKER_01'},
#   ...]}
